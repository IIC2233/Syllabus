# %% [markdown]
# <p>
# <font size='5' face='Georgia, Arial'>IIC2233 Taller Programación Avanzada</font><br>
# <font size='1'>
#     &copy; 2024-2 Daniela Concha. Todos los derechos reservados.
# </font>
# </p>
#
# # Simulación de Eventos

# %% [markdown]
# ### Paso 0: Instalar e importar librerías

# %% [markdown]
# En caso de no tener las librerías necesarias instaladas, ejecuta la siguiente línea de código en la terminal de tu computador:
# ```bash
# python3 -m pip install numpy, matplotlib, pandas
# ```
# Recuerda que si `python3` no funciona, pruena con `python`, `py`, `py3` o el compando que utilizas para ejecutar Python3.11 desde tu terminal.

# %%
from collections import deque

import json
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Paso 1: Conocer nuestro problema

# %% [markdown]
# Hablemos sobre el problema que se nos presenta 🐢💬.

# %% [markdown]
# ### Paso 2: Definir clases

# %% [markdown]
# Al momento de realizar la simulación -independientemente de si es una simulación _tick-by-tick_ o por eventos- siempre será necesario modelar:
# * Las **personas** que irán a comprar almuerzos.
# * Los **puestos de comida** que venderán almuerzos.
#
# Hagamos estas clases, pero con lo más básico que necesiten:

# %%
class Persona:
    pid = 0

    def __init__(self) -> None:
        self.pid = Persona.pid
        Persona.pid += 1

        self.dinero = 1000
        self.almuerzo_comprado = False

    def __repr__(self) -> str:
        '''
        Retorna el id de la persona.
        '''
        return f'Persona({self.pid:0>3d})'

# %%
class PuestoComida:
    def __init__(self, nombre: str, productos: dict) -> None:
        self.nombre = nombre
        self.ganancias = 0
        self.productos_vendidos = 0
        self.cola_clientes = deque()

        self.productos_precios = {p['nombre']: p['precio'] for p in productos}
        self.productos_stock = {p['nombre']: p['stock'] for p in productos}

    def __repr__(self) -> str:
        '''
        Retorna un string con el nombre del Puesto de Comida,
        la cantidad total de productos en stock.
        '''
        stock_total = sum(self.productos_stock.values())
        return f'PuestoComida({self.nombre}, {stock_total})'

# %% [markdown]
# ### Paso 3: Cargar información e intanciar clases

# %%
[Persona() for _ in range(5)]
# Out:
# [Persona(000), Persona(001), Persona(002), Persona(003), Persona(004)]

# %%
def cargar_puestos_comida(path_archivo: str) -> list:
    with open(path_archivo, 'r') as file:
        data = json.load(file)

    puestos = [PuestoComida(**p) for p in data]
    return puestos

# %%
cargar_puestos_comida('PuestoComida.json')
# Out:
# [PuestoComida(Empanadas Marcianas, 320),
#  PuestoComida(Completología, 520),
#  PuestoComida(Hand-Rororoll, 160)]

# %% [markdown]
# ### Paso 4: Evaluar distribuciones de probabilidad

# %% [markdown]
# Antes de ponernos a implementar la simulación, deberemos cuestionarnos cómo distribuirán los factores de la misma. En este caso:
# * La **hora** en la que las personas van a comprar sus almuerzos.
# * La **cantidad de dinero** que tienen para pagar.

# %% [markdown]
# #### A) Hora en que las personas van a comprar sus almuerzos

# %%
def weibull(x: float, shape, n) -> float:
    return (shape / n) * (x / n) ** (shape - 1) * np.exp(-(x / n) ** shape)

shape = 15
delta = 1

x = np.arange(50, 120) / 100
y = weibull(x, shape, delta)

fig = plt.figure()
ax = plt.subplot(111)

count, bins, ignored = ax.hist(np.random.weibull(shape, 1000), label='Muestra')

scale = count.max() / y.max()
ax.plot(x, y * scale, label='Función Densidad')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Distribución Weibull')
plt.show()

# %% [markdown]
# #### B) Cantidad de dinero disponible para pagar

# %%
x = np.arange(0, 600) / 600
y = np.ones(len(x))

fig = plt.figure()
ax = plt.subplot(111)

count, bins, ignored = ax.hist(np.random.rand(1000), bins=50, label='Muestra')

scale = count.sum() / len(count)
ax.plot(x, y * scale, label='Función Densidad')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Distribución Uniforme')
plt.show()

# %% [markdown]
# ### Paso 5: Simular

# %% [markdown]
# #### A) Simulación _tick-by-tick_

# %%
import SimulacionTick

simulación_tick_by_tick = SimulacionTick.Simulación(600)
simulación_tick_by_tick.start(600)
# Out:
#                                          INICIO SIMULACIÓN
#
#
# -----------------------------------------------08:30------------------------------------------------
#
# -----------------------------------------------08:31------------------------------------------------
#
# -----------------------------------------------08:32------------------------------------------------
#
# -----------------------------------------------08:33------------------------------------------------
#
# -----------------------------------------------08:34------------------------------------------------
#
# -----------------------------------------------08:35------------------------------------------------
#
# -----------------------------------------------08:36------------------------------------------------
#
# -----------------------------------------------08:37------------------------------------------------
#
# -----------------------------------------------08:38------------------------------------------------
#
# -----------------------------------------------08:39------------------------------------------------
#
# -----------------------------------------------08:40------------------------------------------------
#
# -----------------------------------------------08:41------------------------------------------------
#
# -----------------------------------------------08:42------------------------------------------------
#
# -----------------------------------------------08:43------------------------------------------------
#
# -----------------------------------------------08:44------------------------------------------------
#
# -----------------------------------------------08:45------------------------------------------------
#
# -----------------------------------------------08:46------------------------------------------------
#
# -----------------------------------------------08:47------------------------------------------------
#
# -----------------------------------------------08:48------------------------------------------------
#
# -----------------------------------------------08:49------------------------------------------------
#
# -----------------------------------------------08:50------------------------------------------------
#
# -----------------------------------------------08:51------------------------------------------------
#
# -----------------------------------------------08:52------------------------------------------------
#
# -----------------------------------------------08:53------------------------------------------------
#
# -----------------------------------------------08:54------------------------------------------------
#
# -----------------------------------------------08:55------------------------------------------------
#
# -----------------------------------------------08:56------------------------------------------------
#
# -----------------------------------------------08:57------------------------------------------------
#
# -----------------------------------------------08:58------------------------------------------------
#
# -----------------------------------------------08:59------------------------------------------------
#
# -----------------------------------------------09:00------------------------------------------------
#
# -----------------------------------------------09:01------------------------------------------------
#
# -----------------------------------------------09:02------------------------------------------------
#
# -----------------------------------------------09:03------------------------------------------------
#
# -----------------------------------------------09:04------------------------------------------------
#
# -----------------------------------------------09:05------------------------------------------------
#
# -----------------------------------------------09:06------------------------------------------------
#
# -----------------------------------------------09:07------------------------------------------------
#
# -----------------------------------------------09:08------------------------------------------------
#
# -----------------------------------------------09:09------------------------------------------------
#
# -----------------------------------------------09:10------------------------------------------------
#
# -----------------------------------------------09:11------------------------------------------------
#
# -----------------------------------------------09:12------------------------------------------------
#
# -----------------------------------------------09:13------------------------------------------------
#
# -----------------------------------------------09:14------------------------------------------------
#
# -----------------------------------------------09:15------------------------------------------------
#
# -----------------------------------------------09:16------------------------------------------------
#
# -----------------------------------------------09:17------------------------------------------------
#
# -----------------------------------------------09:18------------------------------------------------
#
# -----------------------------------------------09:19------------------------------------------------
#
# -----------------------------------------------09:20------------------------------------------------
#
# -----------------------------------------------09:21------------------------------------------------
#
# -----------------------------------------------09:22------------------------------------------------
#
# -----------------------------------------------09:23------------------------------------------------
#
# -----------------------------------------------09:24------------------------------------------------
#
# -----------------------------------------------09:25------------------------------------------------
#
# -----------------------------------------------09:26------------------------------------------------
#
# -----------------------------------------------09:27------------------------------------------------
#
# -----------------------------------------------09:28------------------------------------------------
#
# -----------------------------------------------09:29------------------------------------------------
#
# -----------------------------------------------09:30------------------------------------------------
#
# -----------------------------------------------09:31------------------------------------------------
#
# -----------------------------------------------09:32------------------------------------------------
#
# -----------------------------------------------09:33------------------------------------------------
#
# -----------------------------------------------09:34------------------------------------------------
#
# -----------------------------------------------09:35------------------------------------------------
#
# -----------------------------------------------09:36------------------------------------------------
#
# -----------------------------------------------09:37------------------------------------------------
#
# -----------------------------------------------09:38------------------------------------------------
#
# -----------------------------------------------09:39------------------------------------------------
#
# -----------------------------------------------09:40------------------------------------------------
#
# -----------------------------------------------09:41------------------------------------------------
#
# -----------------------------------------------09:42------------------------------------------------
#
# -----------------------------------------------09:43------------------------------------------------
#
# -----------------------------------------------09:44------------------------------------------------
#
# -----------------------------------------------09:45------------------------------------------------
#
# -----------------------------------------------09:46------------------------------------------------
#
# -----------------------------------------------09:47------------------------------------------------
#
# -----------------------------------------------09:48------------------------------------------------
#
# -----------------------------------------------09:49------------------------------------------------
#
# -----------------------------------------------09:50------------------------------------------------
#
# -----------------------------------------------09:51------------------------------------------------
#
# -----------------------------------------------09:52------------------------------------------------
#
# -----------------------------------------------09:53------------------------------------------------
#
# -----------------------------------------------09:54------------------------------------------------
#
# -----------------------------------------------09:55------------------------------------------------
#
# -----------------------------------------------09:56------------------------------------------------
#
# -----------------------------------------------09:57------------------------------------------------
#
# -----------------------------------------------09:58------------------------------------------------
#
# -----------------------------------------------09:59------------------------------------------------
#
# -----------------------------------------------10:00------------------------------------------------
#
# -----------------------------------------------10:01------------------------------------------------
#
# -----------------------------------------------10:02------------------------------------------------
#
# -----------------------------------------------10:03------------------------------------------------
#
# -----------------------------------------------10:04------------------------------------------------
#
# -----------------------------------------------10:05------------------------------------------------
#
# -----------------------------------------------10:06------------------------------------------------
#
# -----------------------------------------------10:07------------------------------------------------
#
# -----------------------------------------------10:08------------------------------------------------
#
# -----------------------------------------------10:09------------------------------------------------
#
# -----------------------------------------------10:10------------------------------------------------
#
# -----------------------------------------------10:11------------------------------------------------
#
# -----------------------------------------------10:12------------------------------------------------
#
# -----------------------------------------------10:13------------------------------------------------
#
# -----------------------------------------------10:14------------------------------------------------
#
# -----------------------------------------------10:15------------------------------------------------
#
# -----------------------------------------------10:16------------------------------------------------
#
# -----------------------------------------------10:17------------------------------------------------
#
# -----------------------------------------------10:18------------------------------------------------
#
# -----------------------------------------------10:19------------------------------------------------
#
# -----------------------------------------------10:20------------------------------------------------
#
# -----------------------------------------------10:21------------------------------------------------
#
# -----------------------------------------------10:22------------------------------------------------
#
# -----------------------------------------------10:23------------------------------------------------
#
# -----------------------------------------------10:24------------------------------------------------
#
# -----------------------------------------------10:25------------------------------------------------
#
# -----------------------------------------------10:26------------------------------------------------
#
# -----------------------------------------------10:27------------------------------------------------
#
# -----------------------------------------------10:28------------------------------------------------
#
# -----------------------------------------------10:29------------------------------------------------
#
# -----------------------------------------------10:30------------------------------------------------
#
# -----------------------------------------------10:31------------------------------------------------
#
# -----------------------------------------------10:32------------------------------------------------
#
# -----------------------------------------------10:33------------------------------------------------
#
# -----------------------------------------------10:34------------------------------------------------
#
# -----------------------------------------------10:35------------------------------------------------
#
# -----------------------------------------------10:36------------------------------------------------
#
# -----------------------------------------------10:37------------------------------------------------
#
# -----------------------------------------------10:38------------------------------------------------
#
# -----------------------------------------------10:39------------------------------------------------
#
# -----------------------------------------------10:40------------------------------------------------
#
# -----------------------------------------------10:41------------------------------------------------
#
# -----------------------------------------------10:42------------------------------------------------
#
# -----------------------------------------------10:43------------------------------------------------
#
# -----------------------------------------------10:44------------------------------------------------
#
# -----------------------------------------------10:45------------------------------------------------
#
# -----------------------------------------------10:46------------------------------------------------
#
# -----------------------------------------------10:47------------------------------------------------
#
# -----------------------------------------------10:48------------------------------------------------
#
# -----------------------------------------------10:49------------------------------------------------
#
# -----------------------------------------------10:50------------------------------------------------
#
# -----------------------------------------------10:51------------------------------------------------
#
# -----------------------------------------------10:52------------------------------------------------
#
# -----------------------------------------------10:53------------------------------------------------
#
# -----------------------------------------------10:54------------------------------------------------
#
# -----------------------------------------------10:55------------------------------------------------
#
# -----------------------------------------------10:56------------------------------------------------
#
# -----------------------------------------------10:57------------------------------------------------
#
# -----------------------------------------------10:58------------------------------------------------
#
# -----------------------------------------------10:59------------------------------------------------
#
# -----------------------------------------------11:00------------------------------------------------
#
# -----------------------------------------------11:01------------------------------------------------
#
# -----------------------------------------------11:02------------------------------------------------
#
# -----------------------------------------------11:03------------------------------------------------
#
# -----------------------------------------------11:04------------------------------------------------
#
# -----------------------------------------------11:05------------------------------------------------
#
# -----------------------------------------------11:06------------------------------------------------
#
# -----------------------------------------------11:07------------------------------------------------
#
# -----------------------------------------------11:08------------------------------------------------
#
# -----------------------------------------------11:09------------------------------------------------
#
# -----------------------------------------------11:10------------------------------------------------
#
# -----------------------------------------------11:11------------------------------------------------
#
# -----------------------------------------------11:12------------------------------------------------
#
# -----------------------------------------------11:13------------------------------------------------
#
# -----------------------------------------------11:14------------------------------------------------
#
# -----------------------------------------------11:15------------------------------------------------
#
# -----------------------------------------------11:16------------------------------------------------
#
# -----------------------------------------------11:17------------------------------------------------
#
# -----------------------------------------------11:18------------------------------------------------
#
# -----------------------------------------------11:19------------------------------------------------
#
# -----------------------------------------------11:20------------------------------------------------
#
# -----------------------------------------------11:21------------------------------------------------
#
# -----------------------------------------------11:22------------------------------------------------
#
# -----------------------------------------------11:23------------------------------------------------
#
# -----------------------------------------------11:24------------------------------------------------
#
# -----------------------------------------------11:25------------------------------------------------
#
# -----------------------------------------------11:26------------------------------------------------
#
# -----------------------------------------------11:27------------------------------------------------
#
# -----------------------------------------------11:28------------------------------------------------
#
# -----------------------------------------------11:29------------------------------------------------
#
# -----------------------------------------------11:30------------------------------------------------
#
# -----------------------------------------------11:31------------------------------------------------
#
# -----------------------------------------------11:32------------------------------------------------
#
# -----------------------------------------------11:33------------------------------------------------
#
# -----------------------------------------------11:34------------------------------------------------
#
# -----------------------------------------------11:35------------------------------------------------
#
# -----------------------------------------------11:36------------------------------------------------
# [    Completología    ]	 El cliente (256) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (256) empezó a ser atendido.
# [    Completología    ]	 El cliente (256) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------11:37------------------------------------------------
#
# -----------------------------------------------11:38------------------------------------------------
#
# -----------------------------------------------11:39------------------------------------------------
#
# -----------------------------------------------11:40------------------------------------------------
#
# -----------------------------------------------11:41------------------------------------------------
#
# -----------------------------------------------11:42------------------------------------------------
#
# -----------------------------------------------11:43------------------------------------------------
#
# -----------------------------------------------11:44------------------------------------------------
#
# -----------------------------------------------11:45------------------------------------------------
#
# -----------------------------------------------11:46------------------------------------------------
#
# -----------------------------------------------11:47------------------------------------------------
#
# -----------------------------------------------11:48------------------------------------------------
#
# -----------------------------------------------11:49------------------------------------------------
#
# -----------------------------------------------11:50------------------------------------------------
#
# -----------------------------------------------11:51------------------------------------------------
#
# -----------------------------------------------11:52------------------------------------------------
#
# -----------------------------------------------11:53------------------------------------------------
#
# -----------------------------------------------11:54------------------------------------------------
#
# -----------------------------------------------11:55------------------------------------------------
#
# -----------------------------------------------11:56------------------------------------------------
#
# -----------------------------------------------11:57------------------------------------------------
#
# -----------------------------------------------11:58------------------------------------------------
# [    Completología    ]	 El cliente (362) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (362) empezó a ser atendido.
# [    Completología    ]	 El cliente (362) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------11:59------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (493) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (493) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (493) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# -----------------------------------------------12:00------------------------------------------------
# [    Completología    ]	 El cliente (493) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (493) empezó a ser atendido.
# [    Completología    ]	 El cliente (493) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------12:01------------------------------------------------
#
# -----------------------------------------------12:02------------------------------------------------
#
# -----------------------------------------------12:03------------------------------------------------
#
# -----------------------------------------------12:04------------------------------------------------
#
# -----------------------------------------------12:05------------------------------------------------
#
# -----------------------------------------------12:06------------------------------------------------
#
# -----------------------------------------------12:07------------------------------------------------
#
# -----------------------------------------------12:08------------------------------------------------
#
# -----------------------------------------------12:09------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (417) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (417) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (417) compró un "Saturno". El local ganó $3000
#
# -----------------------------------------------12:10------------------------------------------------
# [    Completología    ]	 El cliente (118) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (559) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (118) empezó a ser atendido.
# [    Completología    ]	 El cliente (118) compró un "Pancho". El local ganó $2000
# [    Hand-Rororoll    ]	 El cliente (559) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (559) compró un "Kanikama". El local ganó $2800
#
# -----------------------------------------------12:11------------------------------------------------
#
# -----------------------------------------------12:12------------------------------------------------
#
# -----------------------------------------------12:13------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (202) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (202) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (202) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# -----------------------------------------------12:14------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (453) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (202) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (453) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (453) compró un "Mercurio". El local ganó $3000
# [    Completología    ]	 El cliente (202) empezó a ser atendido.
# [    Completología    ]	 El cliente (202) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------12:15------------------------------------------------
# [    Completología    ]	 El cliente (106) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (106) empezó a ser atendido.
# [    Completología    ]	 El cliente (106) compró un "Dinámico". El local ganó $3500
#
# -----------------------------------------------12:16------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (517) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (517) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (517) compró un "Kanikama". El local ganó $2800
#
# -----------------------------------------------12:17------------------------------------------------
#
# -----------------------------------------------12:18------------------------------------------------
# [    Completología    ]	 El cliente (515) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (515) empezó a ser atendido.
# [    Completología    ]	 El cliente (515) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------12:19------------------------------------------------
#
# -----------------------------------------------12:20------------------------------------------------
# [    Completología    ]	 El cliente (445) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (445) empezó a ser atendido.
# [    Completología    ]	 El cliente (445) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------12:21------------------------------------------------
#
# -----------------------------------------------12:22------------------------------------------------
#
# -----------------------------------------------12:23------------------------------------------------
# [    Completología    ]	 El cliente (452) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (452) empezó a ser atendido.
# [    Completología    ]	 El cliente (452) compró un "Dinámico". El local ganó $3500
#
# -----------------------------------------------12:24------------------------------------------------
# [    Completología    ]	 El cliente (074) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (074) empezó a ser atendido.
# [    Completología    ]	 El cliente (074) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------12:25------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (346) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (323) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (346) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (346) compró un "Marte". El local ganó $3000
# [ Empanadas Marcianas ]	 El cliente (323) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (323) compró un "Mercurio". El local ganó $3000
#
# -----------------------------------------------12:26------------------------------------------------
#
# -----------------------------------------------12:27------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (250) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (250) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (250) compró un "Kanikama". El local ganó $2800
#
# -----------------------------------------------12:28------------------------------------------------
#
# -----------------------------------------------12:29------------------------------------------------
#
# -----------------------------------------------12:30------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (289) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (289) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (289) compró un "Saturno". El local ganó $3000
#
# -----------------------------------------------12:31------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (205) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (205) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (205) compró un "Atún". El local ganó $4000
#
# -----------------------------------------------12:32------------------------------------------------
# [    Completología    ]	 El cliente (538) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (538) empezó a ser atendido.
# [    Completología    ]	 El cliente (538) compró un "Luco". El local ganó $3000
#
# -----------------------------------------------12:33------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (502) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (218) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (086) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (218) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (218) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [ Empanadas Marcianas ]	 El cliente (086) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (086) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Hand-Rororoll    ]	 El cliente (502) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (502) compró un "Atún". El local ganó $4000
#
# -----------------------------------------------12:34------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (544) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (557) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (358) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (167) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (086) se a unido a la cola. Hay 3 clientes esperando.
# [    Completología    ]	 El cliente (218) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (167) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (167) compró un "Urano". El local ganó $3800
# [    Completología    ]	 El cliente (358) empezó a ser atendido.
# [    Completología    ]	 El cliente (358) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (218) empezó a ser atendido.
# [    Completología    ]	 El cliente (218) compró un "Pancho". El local ganó $2000
# [    Hand-Rororoll    ]	 El cliente (544) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (544) compró un "Camarón". El local ganó $3500
# [    Hand-Rororoll    ]	 El cliente (557) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (557) compró un "Kanikama". El local ganó $2800
# [    Hand-Rororoll    ]	 El cliente (086) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (086) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# -----------------------------------------------12:35------------------------------------------------
# [    Completología    ]	 El cliente (570) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (086) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (049) se a unido a la cola. Hay 3 clientes esperando.
# [    Completología    ]	 El cliente (570) empezó a ser atendido.
# [    Completología    ]	 El cliente (570) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (086) empezó a ser atendido.
# [    Completología    ]	 El cliente (086) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (049) empezó a ser atendido.
# [    Completología    ]	 El cliente (049) compró un "Luco". El local ganó $3000
#
# -----------------------------------------------12:36------------------------------------------------
#
# -----------------------------------------------12:37------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (223) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (425) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (425) empezó a ser atendido.
# [    Completología    ]	 El cliente (425) compró un "Especial M&M". El local ganó $3800
# [    Hand-Rororoll    ]	 El cliente (223) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (223) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# -----------------------------------------------12:38------------------------------------------------
# [    Completología    ]	 El cliente (111) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (223) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (529) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (111) empezó a ser atendido.
# [    Completología    ]	 El cliente (111) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (223) empezó a ser atendido.
# [    Completología    ]	 El cliente (223) compró un "Pancho". El local ganó $2000
# [    Hand-Rororoll    ]	 El cliente (529) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (529) compró un "Camarón". El local ganó $3500
#
# -----------------------------------------------12:39------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (409) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (226) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (478) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (478) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (478) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (226) empezó a ser atendido.
# [    Completología    ]	 El cliente (226) compró un "Pancho". El local ganó $2000
# [    Hand-Rororoll    ]	 El cliente (409) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (409) compró un "Camarón". El local ganó $3500
#
# -----------------------------------------------12:40------------------------------------------------
# [    Completología    ]	 El cliente (478) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (148) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (478) empezó a ser atendido.
# [    Completología    ]	 El cliente (478) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (148) empezó a ser atendido.
# [    Completología    ]	 El cliente (148) compró un "Italiano". El local ganó $3500
#
# -----------------------------------------------12:41------------------------------------------------
# [    Completología    ]	 El cliente (068) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (093) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (068) empezó a ser atendido.
# [    Completología    ]	 El cliente (068) compró un "Luco". El local ganó $3000
# [    Completología    ]	 El cliente (093) empezó a ser atendido.
# [    Completología    ]	 El cliente (093) compró un "Dinámico". El local ganó $3500
#
# -----------------------------------------------12:42------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (329) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (044) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (383) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (044) empezó a ser atendido.
# [    Completología    ]	 El cliente (044) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (383) empezó a ser atendido.
# [    Completología    ]	 El cliente (383) compró un "Pancho". El local ganó $2000
# [    Hand-Rororoll    ]	 El cliente (329) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (329) compró un "Kanikama". El local ganó $2800
#
# -----------------------------------------------12:43------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (153) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (153) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (153) compró un "Kanikama". El local ganó $2800
#
# -----------------------------------------------12:44------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (558) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (541) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (558) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (558) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (541) empezó a ser atendido.
# [    Completología    ]	 El cliente (541) compró un "Luco". El local ganó $3000
#
# -----------------------------------------------12:45------------------------------------------------
# [    Completología    ]	 El cliente (558) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (558) empezó a ser atendido.
# [    Completología    ]	 El cliente (558) compró un "Pancho". El local ganó $2000
#
# -----------------------------------------------12:46------------------------------------------------
# [    Completología    ]	 El cliente (033) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (285) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (196) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (285) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (285) compró un "Urano". El local ganó $3800
# [    Completología    ]	 El cliente (033) empezó a ser atendido.
# [    Completología    ]	 El cliente (033) compró un "Dinámico". El local ganó $3500
# [    Completología    ]	 El cliente (196) empezó a ser atendido.
# [    Completología    ]	 El cliente (196) compró un "Especial M&M". El local ganó $3800
#
# -----------------------------------------------12:47------------------------------------------------
# [    Completología    ]	 El cliente (029) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (136) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (029) empezó a ser atendido.
# [    Completología    ]	 El cliente (029) compró un "Luco". El local ganó $3000
# [    Hand-Rororoll    ]	 El cliente (136) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (136) compró un "Camarón apanado". El local ganó $4000
#
# -----------------------------------------------12:48------------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (270) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (536) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (442) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (354) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (270) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (270) compró un "Saturno". El local ganó $3000
# [ Empanadas Marcianas ]	 El cliente (442) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (442) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Hand-Rororoll    ]	 El cliente (536) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (536) compró un "Kanikama". El local ganó $2800
# [    Hand-Rororoll    ]	 El cliente (354) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (354) compró un "Atún". El local ganó $4000
#
# -----------------------------------------------12:49------------------------------------------------
# [    Completología    ]	 El cliente (485) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (057) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (119) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (442) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (057) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (057) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [ Empanadas Marcianas ]	 El cliente (119) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (119) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (485) empezó a ser atendido.
# [    Completología    ]	 El cliente (485) compró un "Dinámico". El local ganó $3500
# [    Hand-Rororoll    ]	 El cliente (442) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (442) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# -----------------------------------------------12:50------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (277) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (184) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (057) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (532) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (144) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (442) se a unido a la cola. Hay 3 clientes esperando.
# [    Completología    ]	 El cliente (487) se a unido a la cola. Hay 4 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (430) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (119) se a unido a la cola. Hay 3 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (532) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (532) compró un "Mercurio". El local ganó $3000
# [ Empanadas Marcianas ]	 El cliente (430) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (430) compró un "Venus". El local ganó $3500
# [    Completología    ]	 El cliente (184) empezó a ser atendido.
# [    Completología    ]	 El cliente (184) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (144) empezó a ser atendido.
# [    Completología    ]	 El cliente (144) compró un "Luco". El local ganó $3000
# [    Completología    ]	 El cliente (442) empezó a ser atendido.
# [    Completología    ]	 El cliente (442) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (487) empezó a ser atendido.
# [    Completología    ]	 El cliente (487) compró un "Pancho". El local ganó $2000
# [    Hand-Rororoll    ]	 El cliente (277) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (277) compró un "Camarón apanado". El local ganó $4000
# [    Hand-Rororoll    ]	 El cliente (057) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (057) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Hand-Rororoll    ]	 El cliente (119) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (119) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# -----------------------------------------------12:51------------------------------------------------
# [    Completología    ]	 El cliente (119) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (057) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (108) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (341) se a unido a la cola. Hay 3 clientes esperando.
# [    Completología    ]	 El cliente (119) empezó a ser atendido.
# [    Completología    ]	 El cliente (119) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (057) empezó a ser atendido.
# [    Completología    ]	 El cliente (057) compró un "Pancho". El local ganó $2000
# [    Completología    ]	 El cliente (341) empezó a ser atendido.
# [    Completología    ]	 El cliente (341) compró un "Luco". El local ganó $3000
# [    Hand-Rororoll    ]	 El cliente (108) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (108) compró un "Pollo tereyaki". El local ganó $3500
#
# -----------------------------------------------12:52------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (070) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (141) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (135) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (011) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (553) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (141) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (141) compró un "Urano". El local ganó $3800
# [ Empanadas Marcianas ]	 El cliente (011) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (011) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (135) empezó a ser atendido.
# [    Completología    ]	 El cliente (135) compró un "Luco". El local ganó $3000
# [    Hand-Rororoll    ]	 El cliente (070) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (070) compró un "Camarón apanado". El local ganó $4000
# [    Hand-Rororoll    ]	 El cliente (553) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (553) compró un "Kanikama". El local ganó $2800
#
# -----------------------------------------------12:53------------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (516) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (311) se a unido a la cola. Hay 1 clientes esperando.
# [    Completología    ]	 El cliente (011) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (443) se a unido a la cola. Hay 3 clientes esperando.
# [    Completología    ]	 El cliente (311) empezó a ser atendido.
# [    Completología    ]	 El cliente (311) compró un "Pancho". El local ganó $2000
# ...
#
# -----------------------------------------------15:54------------------------------------------------
#
# -----------------------------------------------15:55------------------------------------------------
#
# -----------------------------------------------15:56------------------------------------------------
#
# -----------------------------------------------15:57------------------------------------------------
#
# -----------------------------------------------15:58------------------------------------------------
#
# -----------------------------------------------15:59------------------------------------------------
#
# -----------------------------------------------16:00------------------------------------------------
#
# -----------------------------------------------16:01------------------------------------------------
#
# -----------------------------------------------16:02------------------------------------------------
#
# -----------------------------------------------16:03------------------------------------------------
#
# -----------------------------------------------16:04------------------------------------------------
#
# -----------------------------------------------16:05------------------------------------------------
#
# -----------------------------------------------16:06------------------------------------------------
#
# -----------------------------------------------16:07------------------------------------------------
#
# -----------------------------------------------16:08------------------------------------------------
#
# -----------------------------------------------16:09------------------------------------------------
#
# -----------------------------------------------16:10------------------------------------------------
#
# -----------------------------------------------16:11------------------------------------------------
#
# -----------------------------------------------16:12------------------------------------------------
#
# -----------------------------------------------16:13------------------------------------------------
#
# -----------------------------------------------16:14------------------------------------------------
#
# -----------------------------------------------16:15------------------------------------------------
#
# -----------------------------------------------16:16------------------------------------------------
#
# -----------------------------------------------16:17------------------------------------------------
#
# -----------------------------------------------16:18------------------------------------------------
#
# -----------------------------------------------16:19------------------------------------------------
#
# -----------------------------------------------16:20------------------------------------------------
#
# -----------------------------------------------16:21------------------------------------------------
#
# -----------------------------------------------16:22------------------------------------------------
#
# -----------------------------------------------16:23------------------------------------------------
#
# -----------------------------------------------16:24------------------------------------------------
#
# -----------------------------------------------16:25------------------------------------------------
#
# -----------------------------------------------16:26------------------------------------------------
#
# -----------------------------------------------16:27------------------------------------------------
#
# -----------------------------------------------16:28------------------------------------------------
#
# -----------------------------------------------16:29------------------------------------------------
#
# -----------------------------------------------16:30------------------------------------------------
#
# -----------------------------------------------16:31------------------------------------------------
#
# -----------------------------------------------16:32------------------------------------------------
#
# -----------------------------------------------16:33------------------------------------------------
#
# -----------------------------------------------16:34------------------------------------------------
#
# -----------------------------------------------16:35------------------------------------------------
#
# -----------------------------------------------16:36------------------------------------------------
#
# -----------------------------------------------16:37------------------------------------------------
#
# -----------------------------------------------16:38------------------------------------------------
#
# -----------------------------------------------16:39------------------------------------------------
#
# -----------------------------------------------16:40------------------------------------------------
#
# -----------------------------------------------16:41------------------------------------------------
#
# -----------------------------------------------16:42------------------------------------------------
#
# -----------------------------------------------16:43------------------------------------------------
#
# -----------------------------------------------16:44------------------------------------------------
#
# -----------------------------------------------16:45------------------------------------------------
#
# -----------------------------------------------16:46------------------------------------------------
#
# -----------------------------------------------16:47------------------------------------------------
#
# -----------------------------------------------16:48------------------------------------------------
#
# -----------------------------------------------16:49------------------------------------------------
#
# -----------------------------------------------16:50------------------------------------------------
#
# -----------------------------------------------16:51------------------------------------------------
#
# -----------------------------------------------16:52------------------------------------------------
#
# -----------------------------------------------16:53------------------------------------------------
#
# -----------------------------------------------16:54------------------------------------------------
#
# -----------------------------------------------16:55------------------------------------------------
#
# -----------------------------------------------16:56------------------------------------------------
#
# -----------------------------------------------16:57------------------------------------------------
#
# -----------------------------------------------16:58------------------------------------------------
#
# -----------------------------------------------16:59------------------------------------------------
#
# -----------------------------------------------17:00------------------------------------------------
#
# -----------------------------------------------17:01------------------------------------------------
#
# -----------------------------------------------17:02------------------------------------------------
#
# -----------------------------------------------17:03------------------------------------------------
#
# -----------------------------------------------17:04------------------------------------------------
#
# -----------------------------------------------17:05------------------------------------------------
#
# -----------------------------------------------17:06------------------------------------------------
#
# -----------------------------------------------17:07------------------------------------------------
#
# -----------------------------------------------17:08------------------------------------------------
#
# -----------------------------------------------17:09------------------------------------------------
#
# -----------------------------------------------17:10------------------------------------------------
#
# -----------------------------------------------17:11------------------------------------------------
#
# -----------------------------------------------17:12------------------------------------------------
#
# -----------------------------------------------17:13------------------------------------------------
#
# -----------------------------------------------17:14------------------------------------------------
#
# -----------------------------------------------17:15------------------------------------------------
#
# -----------------------------------------------17:16------------------------------------------------
#
# -----------------------------------------------17:17------------------------------------------------
#
# -----------------------------------------------17:18------------------------------------------------
#
# -----------------------------------------------17:19------------------------------------------------
#
# -----------------------------------------------17:20------------------------------------------------
#
# -----------------------------------------------17:21------------------------------------------------
#
# -----------------------------------------------17:22------------------------------------------------
#
# -----------------------------------------------17:23------------------------------------------------
#
# -----------------------------------------------17:24------------------------------------------------
#
# -----------------------------------------------17:25------------------------------------------------
#
# -----------------------------------------------17:26------------------------------------------------
#
# -----------------------------------------------17:27------------------------------------------------
#
# -----------------------------------------------17:28------------------------------------------------
#
# -----------------------------------------------17:29------------------------------------------------
#
# -----------------------------------------------17:30------------------------------------------------
#
# -----------------------------------------------17:31------------------------------------------------
#
# -----------------------------------------------17:32------------------------------------------------
#
# -----------------------------------------------17:33------------------------------------------------
#
# -----------------------------------------------17:34------------------------------------------------
#
# -----------------------------------------------17:35------------------------------------------------
#
# -----------------------------------------------17:36------------------------------------------------
#
# -----------------------------------------------17:37------------------------------------------------
#
# -----------------------------------------------17:38------------------------------------------------
#
# -----------------------------------------------17:39------------------------------------------------
#
# -----------------------------------------------17:40------------------------------------------------
#
# -----------------------------------------------17:41------------------------------------------------
#
# -----------------------------------------------17:42------------------------------------------------
#
# -----------------------------------------------17:43------------------------------------------------
#
# -----------------------------------------------17:44------------------------------------------------
#
# -----------------------------------------------17:45------------------------------------------------
#
# -----------------------------------------------17:46------------------------------------------------
#
# -----------------------------------------------17:47------------------------------------------------
#
# -----------------------------------------------17:48------------------------------------------------
#
# -----------------------------------------------17:49------------------------------------------------
#
# -----------------------------------------------17:50------------------------------------------------
#
# -----------------------------------------------17:51------------------------------------------------
#
# -----------------------------------------------17:52------------------------------------------------
#
# -----------------------------------------------17:53------------------------------------------------
#
# -----------------------------------------------17:54------------------------------------------------
#
# -----------------------------------------------17:55------------------------------------------------
#
# -----------------------------------------------17:56------------------------------------------------
#
# -----------------------------------------------17:57------------------------------------------------
#
# -----------------------------------------------17:58------------------------------------------------
#
# -----------------------------------------------17:59------------------------------------------------
#
# -----------------------------------------------18:00------------------------------------------------
#
# -----------------------------------------------18:01------------------------------------------------
#
# -----------------------------------------------18:02------------------------------------------------
#
# -----------------------------------------------18:03------------------------------------------------
#
# -----------------------------------------------18:04------------------------------------------------
#
# -----------------------------------------------18:05------------------------------------------------
#
# -----------------------------------------------18:06------------------------------------------------
#
# -----------------------------------------------18:07------------------------------------------------
#
# -----------------------------------------------18:08------------------------------------------------
#
# -----------------------------------------------18:09------------------------------------------------
#
# -----------------------------------------------18:10------------------------------------------------
#
# -----------------------------------------------18:11------------------------------------------------
#
# -----------------------------------------------18:12------------------------------------------------
#
# -----------------------------------------------18:13------------------------------------------------
#
# -----------------------------------------------18:14------------------------------------------------
#
# -----------------------------------------------18:15------------------------------------------------
#
# -----------------------------------------------18:16------------------------------------------------
#
# -----------------------------------------------18:17------------------------------------------------
#
# -----------------------------------------------18:18------------------------------------------------
#
# -----------------------------------------------18:19------------------------------------------------
#
# -----------------------------------------------18:20------------------------------------------------
#
# -----------------------------------------------18:21------------------------------------------------
#
# -----------------------------------------------18:22------------------------------------------------
#
# -----------------------------------------------18:23------------------------------------------------
#
# -----------------------------------------------18:24------------------------------------------------
#
# -----------------------------------------------18:25------------------------------------------------
#
# -----------------------------------------------18:26------------------------------------------------
#
# -----------------------------------------------18:27------------------------------------------------
#
# -----------------------------------------------18:28------------------------------------------------
#
# -----------------------------------------------18:29------------------------------------------------
#
#                                            FIN SIMULACIÓN

# %%
simulación_tick_by_tick.stats['atención_clientes']
# Out:
#                            Caso  Cantidad
# 0            Compraron almuerzo       377
# 1  No fueron a comprar almuerzo       209
# 2       No encontraron almuerzo        14
# 3              Les faltó tiempo         0

# %%
simulación_tick_by_tick.stats['ventas_locales']
# Out:
#                 Puesto  Ganancias  Cant. Ventas
# 0  Empanadas Marcianas     286900            90
# 1        Completología     503400           190
# 2        Hand-Rororoll     330000            97

# %% [markdown]
# #### B) Simulación de Eventos Discretos (DES)

# %%
import SimulacionDES

simulación_tick_by_tick = SimulacionDES.Simulación(600)
simulación_tick_by_tick.start()
# Out:
#                                          INICIO SIMULACIÓN
#
#
#
# ----------------------------------------------11:48:13----------------------------------------------
# [    Completología    ]	 El cliente (1080) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------11:48:28----------------------------------------------
# [    Completología    ]	 El cliente (1080) empezó a ser atendido.
# [    Completología    ]	 El cliente (1080) compró un "Luco". El local ganó $3000
#
# ----------------------------------------------11:49:26----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1147) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------11:49:41----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1147) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1147) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:01:37----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (646) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:01:52----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (646) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (646) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:03:57----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1166) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:04:12----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1166) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1166) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------12:08:38----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (636) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:08:49----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (827) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:08:53----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (636) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (636) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (636) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:09:04----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (827) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (827) compró un "Atún". El local ganó $4000
#
# ----------------------------------------------12:09:08----------------------------------------------
# [    Completología    ]	 El cliente (636) empezó a ser atendido.
# [    Completología    ]	 El cliente (636) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:11:48----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (608) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:12:03----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (608) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (608) compró un "Mercurio". El local ganó $3000
#
# ----------------------------------------------12:12:30----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1015) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:12:45----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1015) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1015) compró un "Camarón apanado". El local ganó $4000
#
# ----------------------------------------------12:16:51----------------------------------------------
# [    Completología    ]	 El cliente (1116) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:17:06----------------------------------------------
# [    Completología    ]	 El cliente (1116) empezó a ser atendido.
# [    Completología    ]	 El cliente (1116) compró un "Dinámico". El local ganó $3500
#
# ----------------------------------------------12:18:33----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1051) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:18:35----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (732) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:18:48----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1051) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1051) compró un "Camarón apanado". El local ganó $4000
#
# ----------------------------------------------12:19:03----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (732) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (732) compró un "Pollo tereyaki". El local ganó $3500
#
# ----------------------------------------------12:21:42----------------------------------------------
# [    Completología    ]	 El cliente (1178) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:21:57----------------------------------------------
# [    Completología    ]	 El cliente (1178) empezó a ser atendido.
# [    Completología    ]	 El cliente (1178) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:23:34----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1007) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:23:49----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1007) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1007) compró un "Júpiter". El local ganó $3500
#
# ----------------------------------------------12:23:52----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1078) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:24:07----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1078) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1078) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------12:25:44----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1003) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:25:59----------------------------------------------
# [    Completología    ]	 El cliente (1011) se a unido a la cola. Hay 1 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (1003) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1003) compró un "Saturno". El local ganó $3000
#
# ----------------------------------------------12:26:14----------------------------------------------
# [    Completología    ]	 El cliente (1011) empezó a ser atendido.
# [    Completología    ]	 El cliente (1011) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:27:59----------------------------------------------
# [    Completología    ]	 El cliente (772) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:28:14----------------------------------------------
# [    Completología    ]	 El cliente (772) empezó a ser atendido.
# [    Completología    ]	 El cliente (772) compró un "Especial M&M". El local ganó $3800
#
# ----------------------------------------------12:29:32----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (810) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:29:47----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (810) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (810) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:30:02----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (963) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:30:17----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (963) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (963) compró un "Pollo tereyaki". El local ganó $3500
#
# ----------------------------------------------12:31:17----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (789) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:31:32----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (789) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (789) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:31:33----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (789) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:31:48----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (789) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (789) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:32:48----------------------------------------------
# [    Completología    ]	 El cliente (914) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:32:53----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1042) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:33:03----------------------------------------------
# [    Completología    ]	 El cliente (914) empezó a ser atendido.
# [    Completología    ]	 El cliente (914) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:33:07----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (887) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:33:08----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1042) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1042) compró un "Mercurio". El local ganó $3000
#
# ----------------------------------------------12:33:18----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1112) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:33:23----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (887) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (887) compró un "Urano". El local ganó $3800
#
# ----------------------------------------------12:33:33----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1112) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1112) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:35:28----------------------------------------------
# [    Completología    ]	 El cliente (960) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:35:43----------------------------------------------
# [    Completología    ]	 El cliente (960) empezó a ser atendido.
# [    Completología    ]	 El cliente (960) compró un "Luco". El local ganó $3000
#
# ----------------------------------------------12:37:27----------------------------------------------
# [    Completología    ]	 El cliente (939) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:37:42----------------------------------------------
# [    Completología    ]	 El cliente (939) empezó a ser atendido.
# [    Completología    ]	 El cliente (939) compró un "Especial M&M". El local ganó $3800
#
# ----------------------------------------------12:39:41----------------------------------------------
# [    Completología    ]	 El cliente (869) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:39:56----------------------------------------------
# [    Completología    ]	 El cliente (869) empezó a ser atendido.
# [    Completología    ]	 El cliente (869) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:39:58----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1144) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:40:13----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1144) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1144) compró un "Camarón apanado". El local ganó $4000
#
# ----------------------------------------------12:40:34----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1150) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:40:49----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1150) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1150) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------12:41:04----------------------------------------------
# [    Completología    ]	 El cliente (1089) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:41:10----------------------------------------------
# [    Completología    ]	 El cliente (889) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:41:19----------------------------------------------
# [    Completología    ]	 El cliente (1089) empezó a ser atendido.
# [    Completología    ]	 El cliente (1089) compró un "Italiano". El local ganó $3500
#
# ----------------------------------------------12:41:34----------------------------------------------
# [    Completología    ]	 El cliente (889) empezó a ser atendido.
# [    Completología    ]	 El cliente (889) compró un "Especial M&M". El local ganó $3800
#
# ----------------------------------------------12:41:35----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (974) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:41:50----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (917) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (974) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (974) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:41:51----------------------------------------------
# [    Completología    ]	 El cliente (974) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:42:05----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (917) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (917) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:42:06----------------------------------------------
# [    Completología    ]	 El cliente (917) se a unido a la cola. Hay 2 clientes esperando.
# [    Completología    ]	 El cliente (974) empezó a ser atendido.
# [    Completología    ]	 El cliente (974) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:42:21----------------------------------------------
# [    Completología    ]	 El cliente (917) empezó a ser atendido.
# [    Completología    ]	 El cliente (917) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:42:49----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1136) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:43:04----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1136) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1136) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:43:05----------------------------------------------
# [    Completología    ]	 El cliente (1136) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:43:20----------------------------------------------
# [    Completología    ]	 El cliente (1136) empezó a ser atendido.
# [    Completología    ]	 El cliente (1136) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:43:31----------------------------------------------
# [    Completología    ]	 El cliente (967) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:43:42----------------------------------------------
# [    Completología    ]	 El cliente (1001) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:43:46----------------------------------------------
# [    Completología    ]	 El cliente (967) empezó a ser atendido.
# [    Completología    ]	 El cliente (967) compró un "Italiano". El local ganó $3500
#
# ----------------------------------------------12:43:53----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1062) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:44:01----------------------------------------------
# [    Completología    ]	 El cliente (1001) empezó a ser atendido.
# [    Completología    ]	 El cliente (1001) compró un "Especial M&M". El local ganó $3800
#
# ----------------------------------------------12:44:08----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1062) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1062) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:44:30----------------------------------------------
# [    Completología    ]	 El cliente (707) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:44:45----------------------------------------------
# [    Completología    ]	 El cliente (707) empezó a ser atendido.
# [    Completología    ]	 El cliente (707) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:44:57----------------------------------------------
# [    Completología    ]	 El cliente (1072) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:45:04----------------------------------------------
# [    Completología    ]	 El cliente (1182) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:45:12----------------------------------------------
# [    Completología    ]	 El cliente (1072) empezó a ser atendido.
# [    Completología    ]	 El cliente (1072) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:45:27----------------------------------------------
# [    Completología    ]	 El cliente (1182) empezó a ser atendido.
# [    Completología    ]	 El cliente (1182) compró un "Especial M&M". El local ganó $3800
#
# ----------------------------------------------12:45:32----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (835) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:45:33----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1162) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:45:47----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (835) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (835) compró un "Pollo apanado". El local ganó $3500
#
# ----------------------------------------------12:46:02----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1162) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1162) compró un "Camarón". El local ganó $3500
#
# ----------------------------------------------12:46:16----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (994) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:46:31----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (994) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (994) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Hand-Rororoll    ]	 El cliente (994) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:46:36----------------------------------------------
# [    Completología    ]	 El cliente (656) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:46:43----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (712) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:46:46----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (994) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (994) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:46:51----------------------------------------------
# [    Completología    ]	 El cliente (656) empezó a ser atendido.
# [    Completología    ]	 El cliente (656) compró un "Luco". El local ganó $3000
# [    Completología    ]	 El cliente (655) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:46:53----------------------------------------------
# [    Completología    ]	 El cliente (770) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:47:01----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (712) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (712) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:47:06----------------------------------------------
# [    Completología    ]	 El cliente (655) empezó a ser atendido.
# [    Completología    ]	 El cliente (655) compró un "Dinámico". El local ganó $3500
#
# ----------------------------------------------12:47:20----------------------------------------------
# [    Completología    ]	 El cliente (1029) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:47:21----------------------------------------------
# [    Completología    ]	 El cliente (770) empezó a ser atendido.
# [    Completología    ]	 El cliente (770) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:47:36----------------------------------------------
# [    Completología    ]	 El cliente (1029) empezó a ser atendido.
# [    Completología    ]	 El cliente (1029) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:47:54----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (748) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:47:57----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1192) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:48:07----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (743) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:48:09----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (748) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (748) compró un "Urano". El local ganó $3800
#
# ----------------------------------------------12:48:17----------------------------------------------
# [    Completología    ]	 El cliente (702) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:48:22----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (743) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (743) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:48:24----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1192) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1192) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Hand-Rororoll    ]	 El cliente (1192) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:48:32----------------------------------------------
# [    Completología    ]	 El cliente (702) empezó a ser atendido.
# [    Completología    ]	 El cliente (702) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:48:39----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1192) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1192) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:48:40----------------------------------------------
# [    Completología    ]	 El cliente (1192) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:48:55----------------------------------------------
# [    Completología    ]	 El cliente (1192) empezó a ser atendido.
# [    Completología    ]	 El cliente (1192) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:49:13----------------------------------------------
# [    Completología    ]	 El cliente (709) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:49:25----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (624) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:49:28----------------------------------------------
# [    Completología    ]	 El cliente (709) empezó a ser atendido.
# [    Completología    ]	 El cliente (709) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:49:40----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (624) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (624) compró un "Júpiter". El local ganó $3500
#
# ----------------------------------------------12:49:56----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1172) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:50:10----------------------------------------------
# [    Completología    ]	 El cliente (724) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:50:11----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1172) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1172) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------12:50:17----------------------------------------------
# [    Completología    ]	 El cliente (836) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:50:25----------------------------------------------
# [    Completología    ]	 El cliente (724) empezó a ser atendido.
# [    Completología    ]	 El cliente (724) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:50:40----------------------------------------------
# [    Completología    ]	 El cliente (836) empezó a ser atendido.
# [    Completología    ]	 El cliente (836) compró un "Luco". El local ganó $3000
#
# ----------------------------------------------12:51:00----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (813) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:51:15----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (813) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (813) compró un "Pollo apanado". El local ganó $3500
#
# ----------------------------------------------12:51:27----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1065) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:51:39----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (618) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:51:42----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1065) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1065) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:51:43----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1065) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:51:44----------------------------------------------
# [    Completología    ]	 El cliente (765) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:51:46----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (911) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:51:57----------------------------------------------
# [    Completología    ]	 El cliente (602) se a unido a la cola. Hay 2 clientes esperando.
# [ Empanadas Marcianas ]	 El cliente (618) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (618) compró un "Saturno". El local ganó $3000
#
# ----------------------------------------------12:51:58----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1065) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1065) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (1065) se a unido a la cola. Hay 3 clientes esperando.
#
# ----------------------------------------------12:51:59----------------------------------------------
# [    Completología    ]	 El cliente (765) empezó a ser atendido.
# [    Completología    ]	 El cliente (765) compró un "Luco". El local ganó $3000
#
# ----------------------------------------------12:52:12----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (911) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (911) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:52:13----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (911) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:52:14----------------------------------------------
# [    Completología    ]	 El cliente (602) empezó a ser atendido.
# [    Completología    ]	 El cliente (602) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:52:27----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (859) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:52:28----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (911) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (911) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:52:29----------------------------------------------
# [    Completología    ]	 El cliente (1065) empezó a ser atendido.
# [    Completología    ]	 El cliente (1065) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:52:42----------------------------------------------
# [    Completología    ]	 El cliente (900) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:52:43----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (859) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (859) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (859) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:52:55----------------------------------------------
# [    Completología    ]	 El cliente (663) se a unido a la cola. Hay 3 clientes esperando.
#
# ----------------------------------------------12:52:57----------------------------------------------
# [    Completología    ]	 El cliente (900) empezó a ser atendido.
# [    Completología    ]	 El cliente (900) compró un "Especial M&M". El local ganó $3800
#
# ----------------------------------------------12:53:03----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (997) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:53:08----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (771) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:53:12----------------------------------------------
# [    Completología    ]	 El cliente (859) empezó a ser atendido.
# [    Completología    ]	 El cliente (859) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:53:18----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (997) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (997) compró un "Camarón". El local ganó $3500
#
# ----------------------------------------------12:53:23----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (771) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (771) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:53:24----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (771) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:53:26----------------------------------------------
# [    Completología    ]	 El cliente (661) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:53:27----------------------------------------------
# [    Completología    ]	 El cliente (663) empezó a ser atendido.
# [    Completología    ]	 El cliente (663) compró un "Luco". El local ganó $3000
#
# ----------------------------------------------12:53:39----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (771) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (771) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [ Empanadas Marcianas ]	 El cliente (796) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:53:40----------------------------------------------
# [    Completología    ]	 El cliente (771) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (1129) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:53:42----------------------------------------------
# [    Completología    ]	 El cliente (661) empezó a ser atendido.
# [    Completología    ]	 El cliente (661) compró un "Italiano". El local ganó $3500
#
# ----------------------------------------------12:53:46----------------------------------------------
# [    Completología    ]	 El cliente (1152) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:53:54----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (796) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (796) compró un "Urano". El local ganó $3800
#
# ----------------------------------------------12:53:55----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1129) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1129) compró un "Atún". El local ganó $4000
#
# ----------------------------------------------12:53:57----------------------------------------------
# [    Completología    ]	 El cliente (771) empezó a ser atendido.
# [    Completología    ]	 El cliente (771) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:54:02----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (955) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:54:07----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (844) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:54:12----------------------------------------------
# [    Completología    ]	 El cliente (1152) empezó a ser atendido.
# [    Completología    ]	 El cliente (1152) compró un "Italiano". El local ganó $3500
#
# ----------------------------------------------12:54:15----------------------------------------------
# [    Completología    ]	 El cliente (1013) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:54:17----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (955) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (955) compró un "Atún". El local ganó $4000
#
# ----------------------------------------------12:54:30----------------------------------------------
# [    Completología    ]	 El cliente (1013) empezó a ser atendido.
# [    Completología    ]	 El cliente (1013) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:54:32----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (844) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (844) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:54:41----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (768) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:54:56----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (768) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (768) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:55:18----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (966) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:55:22----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1126) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:55:30----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (929) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:55:33----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (966) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (966) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:55:37----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1126) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1126) compró un "Saturno". El local ganó $3000
#
# ----------------------------------------------12:55:38----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (687) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:55:48----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (929) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (929) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:55:49----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (717) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:55:53----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (687) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (687) compró un "Júpiter". El local ganó $3500
#
# ----------------------------------------------12:55:54----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (973) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:56:00----------------------------------------------
# [    Completología    ]	 El cliente (886) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:56:01----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (706) se a unido a la cola. Hay 3 clientes esperando.
#
# ----------------------------------------------12:56:04----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (717) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (717) compró un "Pollo tereyaki". El local ganó $3500
#
# ----------------------------------------------12:56:08----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (750) se a unido a la cola. Hay 3 clientes esperando.
#
# ----------------------------------------------12:56:15----------------------------------------------
# [    Completología    ]	 El cliente (886) empezó a ser atendido.
# [    Completología    ]	 El cliente (886) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:56:19----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (973) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (973) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:56:24----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (629) se a unido a la cola. Hay 3 clientes esperando.
#
# ----------------------------------------------12:56:26----------------------------------------------
# [    Completología    ]	 El cliente (682) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:56:33----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (952) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:56:34----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (706) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (706) compró un "Kanikama". El local ganó $2800
#
# ----------------------------------------------12:56:41----------------------------------------------
# [    Completología    ]	 El cliente (682) empezó a ser atendido.
# [    Completología    ]	 El cliente (682) compró un "Especial M&M". El local ganó $3800
#
# ----------------------------------------------12:56:48----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (952) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (952) compró un "Saturno". El local ganó $3000
#
# ----------------------------------------------12:56:49----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (750) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (750) compró un "Pollo tereyaki". El local ganó $3500
#
# ----------------------------------------------12:56:56----------------------------------------------
# [    Completología    ]	 El cliente (1019) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:57:04----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (993) se a unido a la cola. Hay 1 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (629) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (629) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------12:57:05----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (629) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:57:07----------------------------------------------
# [    Completología    ]	 El cliente (1176) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:57:11----------------------------------------------
# [    Completología    ]	 El cliente (1019) empezó a ser atendido.
# [    Completología    ]	 El cliente (1019) compró un "Italiano". El local ganó $3500
#
# ----------------------------------------------12:57:14----------------------------------------------
# [    Completología    ]	 El cliente (957) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:57:18----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1137) se a unido a la cola. Hay 3 clientes esperando.
#
# ----------------------------------------------12:57:19----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (993) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (993) compró un "Mercurio". El local ganó $3000
#
# ----------------------------------------------12:57:26----------------------------------------------
# [    Completología    ]	 El cliente (1176) empezó a ser atendido.
# [    Completología    ]	 El cliente (1176) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:57:32----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (988) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:57:34----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (629) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (629) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (629) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------12:57:41----------------------------------------------
# [    Completología    ]	 El cliente (957) empezó a ser atendido.
# [    Completología    ]	 El cliente (957) compró un "Pancho". El local ganó $2000
#
# ----------------------------------------------12:57:47----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (988) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (988) no encontró un producto que pudiese comprar. Se retira decepcionado.
# [    Completología    ]	 El cliente (988) se a unido a la cola. Hay 2 clientes esperando.
# [    Hand-Rororoll    ]	 El cliente (968) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------12:57:48----------------------------------------------
# [    Completología    ]	 El cliente (946) se a unido a la cola. Hay 3 clientes esperando.
#
# ----------------------------------------------12:57:49----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1137) empezó a ser atendido.
# ...
#
# ----------------------------------------------14:01:10----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (861) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:01:23----------------------------------------------
# [    Completología    ]	 El cliente (807) empezó a ser atendido.
# [    Completología    ]	 El cliente (807) compró un "Luco". El local ganó $3000
#
# ----------------------------------------------14:01:24----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (943) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (943) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------14:01:25----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (861) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (861) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:01:26----------------------------------------------
# [                     ]	 El cliente (861) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:01:39----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1109) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1109) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:01:40----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1109) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:01:54----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1149) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1149) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:01:55----------------------------------------------
# [                     ]	 El cliente (1149) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
# [    Hand-Rororoll    ]	 El cliente (1109) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1109) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:01:56----------------------------------------------
# [                     ]	 El cliente (1109) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:02:06----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1099) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:02:09----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (975) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (975) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:02:10----------------------------------------------
# [    Completología    ]	 El cliente (975) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:02:21----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1099) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1099) quería comprar un Atún, pero no está disponible. Se retira decepcionado.
#
# ----------------------------------------------14:02:22----------------------------------------------
# [    Completología    ]	 El cliente (1099) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------14:02:24----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (626) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (626) compró un "Mercurio". El local ganó $3000
#
# ----------------------------------------------14:02:25----------------------------------------------
# [    Completología    ]	 El cliente (975) empezó a ser atendido.
# [    Completología    ]	 El cliente (975) quería comprar un Pancho, pero no está disponible. Se retira decepcionado.
#
# ----------------------------------------------14:02:26----------------------------------------------
# [                     ]	 El cliente (975) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:02:39----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (611) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (611) compró un "Mercurio". El local ganó $3000
#
# ----------------------------------------------14:02:40----------------------------------------------
# [    Completología    ]	 El cliente (1099) empezó a ser atendido.
# [    Completología    ]	 El cliente (1099) compró un "Italiano". El local ganó $3500
#
# ----------------------------------------------14:02:54----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1035) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1035) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------14:02:55----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1138) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:03:01----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (867) se a unido a la cola. Hay 10 clientes esperando.
#
# ----------------------------------------------14:03:09----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1031) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1031) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------14:03:10----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1138) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1138) quería comprar un Atún, pero no está disponible. Se retira decepcionado.
#
# ----------------------------------------------14:03:11----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1138) se a unido a la cola. Hay 10 clientes esperando.
#
# ----------------------------------------------14:03:14----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1052) se a unido a la cola. Hay 11 clientes esperando.
#
# ----------------------------------------------14:03:24----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1061) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1061) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:03:25----------------------------------------------
# [                     ]	 El cliente (1061) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:03:39----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (881) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (881) compró un "Marte". El local ganó $3000
#
# ----------------------------------------------14:03:54----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1086) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1086) compró un "Saturno". El local ganó $3000
#
# ----------------------------------------------14:04:09----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (987) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (987) compró un "Júpiter". El local ganó $3500
#
# ----------------------------------------------14:04:24----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (865) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (865) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:04:25----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (865) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:04:33----------------------------------------------
# [    Completología    ]	 El cliente (934) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:04:39----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1023) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1023) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:04:40----------------------------------------------
# [                     ]	 El cliente (1023) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
# [    Hand-Rororoll    ]	 El cliente (865) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (865) quería comprar un Kanikama, pero no está disponible. Se retira decepcionado.
#
# ----------------------------------------------14:04:41----------------------------------------------
# [                     ]	 El cliente (865) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:04:48----------------------------------------------
# [    Completología    ]	 El cliente (934) empezó a ser atendido.
# [    Completología    ]	 El cliente (934) quería comprar un Pancho, pero no está disponible. Se retira decepcionado.
# [    Hand-Rororoll    ]	 El cliente (934) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:04:54----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1168) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1168) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:04:55----------------------------------------------
# [                     ]	 El cliente (1168) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:05:03----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (934) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (934) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:05:04----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (934) se a unido a la cola. Hay 5 clientes esperando.
#
# ----------------------------------------------14:05:09----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (814) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (814) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:05:10----------------------------------------------
# [                     ]	 El cliente (814) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:05:24----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (867) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (867) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:05:25----------------------------------------------
# [    Completología    ]	 El cliente (867) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:05:39----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1138) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1138) compró un "Urano". El local ganó $3800
#
# ----------------------------------------------14:05:40----------------------------------------------
# [    Completología    ]	 El cliente (867) empezó a ser atendido.
# [    Completología    ]	 El cliente (867) quería comprar un Pancho, pero no está disponible. Se retira decepcionado.
#
# ----------------------------------------------14:05:41----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (867) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:05:54----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (1052) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (1052) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:05:55----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1052) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------14:05:56----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (867) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (867) quería comprar un Kanikama, pero no está disponible. Se retira decepcionado.
# [                     ]	 El cliente (867) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:06:05----------------------------------------------
# [    Completología    ]	 El cliente (902) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:06:09----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (934) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (934) no encontró un producto que pudiese comprar. Se retira decepcionado.
#
# ----------------------------------------------14:06:10----------------------------------------------
# [                     ]	 El cliente (934) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:06:11----------------------------------------------
# [    Hand-Rororoll    ]	 El cliente (1052) empezó a ser atendido.
# [    Hand-Rororoll    ]	 El cliente (1052) quería comprar un Kanikama, pero no está disponible. Se retira decepcionado.
# [    Completología    ]	 El cliente (1052) se a unido a la cola. Hay 2 clientes esperando.
#
# ----------------------------------------------14:06:20----------------------------------------------
# [    Completología    ]	 El cliente (902) empezó a ser atendido.
# [    Completología    ]	 El cliente (902) compró un "Italiano". El local ganó $3500
#
# ----------------------------------------------14:06:35----------------------------------------------
# [    Completología    ]	 El cliente (1052) empezó a ser atendido.
# [    Completología    ]	 El cliente (1052) quería comprar un Pancho, pero no está disponible. Se retira decepcionado.
# [                     ]	 El cliente (1052) ya revisó todos los puestos y no encontró almuerzo. Volverá con hambre a su casa.
#
# ----------------------------------------------14:09:44----------------------------------------------
# [    Completología    ]	 El cliente (1121) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:09:59----------------------------------------------
# [    Completología    ]	 El cliente (1121) empezó a ser atendido.
# [    Completología    ]	 El cliente (1121) compró un "Dinámico". El local ganó $3500
#
# ----------------------------------------------14:10:24----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (760) se a unido a la cola. Hay 1 clientes esperando.
#
# ----------------------------------------------14:10:39----------------------------------------------
# [ Empanadas Marcianas ]	 El cliente (760) empezó a ser atendido.
# [ Empanadas Marcianas ]	 El cliente (760) compró un "Marte". El local ganó $3000
#
#                                            FIN SIMULACIÓN

# %%
simulación_tick_by_tick.stats['atención_clientes']
# Out:
#                            Caso  Cantidad
# 0            Compraron almuerzo       545
# 1  No fueron a comprar almuerzo         0
# 2       No encontraron almuerzo        55
# 3              Les faltó tiempo         0

# %%
simulación_tick_by_tick.stats['ventas_locales']
# Out:
#                 Puesto  Ganancias  Cant. Ventas
# 0  Empanadas Marcianas     584300           182
# 1        Completología     619000           224
# 2        Hand-Rororoll     485500           139
