# %% [markdown]
# # Ayudantía 04: Excepciones/Iterables e Iteradores 📋
#
# ## Ayudantes 👾
# Y sus recomendaciones semanales 🎵
#
# - S1: Josefa Buch
#   - [The Beatles - Now And Then](https://open.spotify.com/track/4vziJcnB2Qyi9o4nIRUeN7?si=DgtkjgFMQmaCX9qWpwDutA&utm_source=copy-link)
# - S2: Bastián Pérez
#   - [Frsotika - Overcooked 2 Soundtrack: Map](https://www.youtube.com/watch?v=-y6J28I5z0c)
# - S3: Carlos Martel
#   - [por definir](https://www.youtube.com/X)
# - S4: André Angulo
#   - [Chimbala x Omega - Se Me Nota (Agarrame)](https://www.youtube.com/watch?v=yxlE4alDecE&list=RDGsLp0CAw-7M&index=2)
# - S5: Juan Pablo Olivares
#   - [por definir](https://www.youtube.com/X)
#
# Con aparición especial de los profes:
# - Daniela Concha
#   - [half•alive - Automatic (acoustic)](https://music.youtube.com/watch?v=sYnpwYePf2A&si=iam-a6AfpVC9T2xb)
# ## Contenidos 📖
#
# - Manejo de Excepciones (`try`, `except`, `finally`)
# - Iterables/Iteradores
# - Listas Ligadas
# - Pseudocódigo (práctica para la prueba escrita)
#
# ## Introducción
# En esta ayudantía, nos centraremos en el manejo de excepciones, una herramienta fundamental para escribir código robusto y evitar que nuestro programa se caiga ante situaciones inesperadas. Además, exploraremos los conceptos de iterables e iteradores, que son esenciales para trabajar con colecciones de datos en Python. Finalmente, veremos las listas ligadas, una estructura de datos que nos permitirá entender mejor cómo funcionan las colecciones dinámicas.

# %% [markdown]
# ## Resumen de Excepciones
#
# ### Tipos de excepciones
#
# | **Excepción** | **Causa** | **Ejemplo** |
# |:---------------|:---------|:---------------|
# | `SyntaxError` | El código rompe las reglas de sintaxis de Python, como no poner paréntesis llamando a una función, no cerrar comillas, etc. | `print "Hola"` |
# | `IndentationError` | Un bloque (`if`, `for`, `def`, ...) no tiene la indentación esperada. Hereda de `SyntaxError` | `if x:\n` seguido de una línea sin indentar |
# | `NameError` | Se usa un nombre (variable, función, clase) que no ha sido definido en el contexto accesible | `print(c)` sin haber definido `c` |
# | `ZeroDivisionError` | El denominador de una división es `0` | `5 / 0` |
# | `IndexError` | Se accede a un índice fuera del rango válido de una secuencia | `(36, 23, 12)[3]` |
# | `KeyError` | Se accede a una llave que no existe en un diccionario | `{"a": 1}["b"]` |
# | `AttributeError` | Se invoca un método o atributo que el objeto no posee | `auto.detenerse()` si `Auto` no define `detenerse` |
# | `TypeError` | Se opera con un **tipo** de dato no válido para esa operación | `2 + [1, 2]` |
# | `ValueError` | El tipo es correcto, pero el **valor** no es apropiado para la operación | `"abc".split("")` |
#
# > 💡 **`SyntaxError` / `IndentationError` vs. el resto:** las dos primeras ocurren al **leer** el programa (no se pueden capturar con `try`/`except` en el mismo archivo); las demás ocurren en **tiempo de ejecución (runtime)**, por lo que sí pueden manejarse.
#
# ### 🧯 Resumen esencial de manejo de excepciones
#
# | **Categoría** | **Comando / Sintaxis** | **Descripción breve** | **Ejemplo** |
# |:--------------|:-----------------------|:----------------------|:------------|
# | **Levantar** | `raise Tipo("mensaje")` | Genera una excepción manualmente e interrumpe el flujo del programa | `raise ValueError("dato inválido")` |
# | **Capturar** | `try: ...`<br>`except Tipo as e: ...` | Ejecuta el bloque `try`; si se lanza `Tipo`, el flujo salta al `except` | `except ZeroDivisionError as e:` |
# | **Varios tipos, un manejo** | `except (TipoA, TipoB) as e:` | Captura distintos tipos de excepción y les da el **mismo** manejo | `except (TypeError, ZeroDivisionError):` |
# | **Varios tipos, manejo distinto** | `except TipoA: ...`<br>`except TipoB: ...` | Usa varios bloques `except` para dar un manejo **diferenciado** por tipo | — |
# | **Si no hubo error** | `else:` | Se ejecuta **solo si** el bloque `try` no lanzó ninguna excepción | `else: print("OK, sin errores")` |
# | **Siempre** | `finally:` | Se ejecuta **siempre**, haya ocurrido una excepción o no | `finally: archivo.close()` |
# | **Definir propia excepción** | `class Mia(Exception): pass` | Crea un nuevo tipo de excepción heredando de `Exception` | `class SaldoInsuficienteError(Exception): pass` |
# | **Acceder al mensaje** | `str(e)` o `f"{e}"` | El objeto capturado en `as e` se imprime como el mensaje del `raise` | `print(f"Error: {e}")` |
#
# > ⚠️ **Orden importa:** en una cadena de `except`, Python evalúa los bloques **en orden** y ejecuta el primero cuyo tipo coincida (o sea superclase) de la excepción lanzada. Por eso conviene poner los `except` más **específicos** antes que los más **genéricos**.

# %% [markdown]
# ## Ejercicio 1: DCCRAFT - ¡EL SERVER SE CAE! 💻
#
# Nos remontamos al año 2012: llegas de la universidad, prendes el PC, vas a ver un video de youtube y lo primero que escuchas es el "turu" del skype. Tu grupo de amigos decidió crear un servidor de Minecraft para construir una réplica a escala de la universidad, pero como no hay presupuesto, están usando **Aternos**. El problema es que Aternos es... bueno, Aternos. A veces la gente intenta entrar con la clave de Facebook, otros intentan salirse del server cuando ya les dio *timeout*, y si tu código no maneja esos errores, el servidor se cerrará y tendrán que esperar una fila de 400 personas otra vez. Justo cuando estás a punto de rendirte por el lag, recuerdas el contenido de la semana de Programación Avanzada... **¡Excepciones!**
#
# La clase `Jugador` ya está implementada, y representa a un usuario cualquiera. Deberás implementar la lógica en la clase `Aternos` para que el sistema sea robusto:
#
# - `Jugador`: representa a un jugador. Tiene los siguientes métodos:
#   - `__init__`: recibe los argumentos `username` y `password`. Define el atributo `conectado` como `False`.
#   - `conectar`: cambia el estado de `conectado` a `True` e imprime `"Sesión iniciada exitosamente"`.
#   - `desconectar`: cambia el estado de `conectado` a `False` e imprime `"Desconexión exitosa"`.
#
# - `Aternos`: representa el servidor que gestiona las sesiones. Tiene los siguientes métodos:
#   - `__init__`: inicializa un diccionario vacío `sesiones` (donde la llave es el *username* y el valor es el objeto `Jugador`).
#
#   - `iniciar_sesion`: recibe un `username` y `password`. Primero, debe intentar (`try`) acceder al jugador en el diccionario. Si la contraseña coincide, llama a su método `conectar`. Si no, imprime `"Contraseña incorrecta"`. Si el jugador no existe en el diccionario, se levantará un `KeyError`; debes capturarlo (`except`) para crear un nuevo objeto `Jugador`, guardarlo en el diccionario e iniciarle la sesión. En este mismo bloque, debes asegurar que la contraseña tenga al menos 8 caracteres, si no lo cumple debes hacer un `raise ValueError("La contraseña debe tener al menos 8 caracteres")`. Finalmente (`finally`), debe imprimir `"Intento de inicio de sesión finalizado"`.
#
#   - `desconectar`: recibe el `username` de un jugador. Debe intentar (`try`) llamar al método `desconectar` del jugador y luego eliminarlo del diccionario de sesiones activas. Si el jugador no se encuentra (levanta un `KeyError`), debe capturar la excepción e imprimir `"El jugador no se encuentra conectado"`. Finalmente (`finally`), debe imprimir `"Intento de desconexión finalizado"`.
#
# > **Hint**: En Python, cuando intentas acceder a una llave que no existe en un diccionario (como `self.sesiones[username]`), el programa lanza un error llamado `KeyError`. ¡Usa los bloques `try` y `except` para manejar este comportamiento y registrar a los usuarios nuevos automáticamente!

# %%
#clases jugador Y aternos. (ocuptar try/except)
class Jugador:
    def __init__(self, username: str, password: str):
        self.username = username
        self.password = password
        self.conectado = False
    
    def conectar(self) -> None:
        self.conectado = True
        print("Sesion iniciada exitosamente")

    def desconectar(self) -> None:
        self.conectado = False
        print("Desconexion exitosa")



class Aternos:
    def __init__(self):
        self.sesiones: dict[str, Jugador] = {} # username : Jugador
    #verificamos que el jugador exista, si existe se conecta, si no existe se crea una nueva sesión y se conecta
    def iniciar_sesion(self, username, password) -> None:
        #si el jugador existe, se verifica la contraseña, si es correcta se conecta, si no es correcta se muestra un mensaje de error
        try:
            if self.sesiones[username].password == password:
                self.sesiones[username].conectar()
        #si la contraseña es incorrecta, se muestra un mensaje de error
            else:
                print("Contraseña incorrecta")
        #si el jugador no existe, se lanza un keyerror, se crea una nueva cuenta y se conecta
        except KeyError:

            if len(password) < 8:
                raise ValueError("La contraseña debe tener al menos 8 caracteres")
            self.sesiones[username] = Jugador(username, password)
            print("Cuenta creada exitosamente")
            self.sesiones[username].conectar()

        #siempre se muestra un mensaje de intento de inicio de sesión finalizado, sin importar si fue exitoso o no
            
        finally:
            print("Intento de inicio de sesión finalizado\n")

    #verificamos que el jugador exista, si no existe no se puede desconectar
    def desconectar(self, jugador_usarname: str) -> None:
        #si el jugador existe, se desconecta y se elimina la sesión.
        try: 
            self.sesiones[jugador_usarname].desconectar()
            del self.sesiones[jugador_usarname]
        #se lanza un keyerror si el jugador no existe, se muestra un mensaje de error
        except KeyError:
            print("El jugador no se encuentra conectado")
        #siempre se muestra un mensaje de intento de desconexión finalizado, sin importar si fue exitoso o no
        finally:
            print("Intento de desconexión finalizado")


#instancia del servidor
aternos = Aternos()

#iniciamos sesión con un jugador nuevo, se crea la sesión y se conecta, probamos que ocurre si intentamos iniciar sesión con el mismo jugador pero con una contraseña incorrecta, y luego con la contraseña correcta
aternos.iniciar_sesion("Bastian", "que_es_el_league_of_legends")
aternos.iniciar_sesion('Bastian', 'que_es_el_league_of_legends')
aternos.iniciar_sesion('Bastian', '1235')

#iniciamos sesión con otros jugadores
aternos.iniciar_sesion('André', "leagueof_legends_me_arruino_la_vida")
aternos.iniciar_sesion('Josefa', "hola_soy_josefa_y_me_gusta_league_of_legends")
aternos.iniciar_sesion('Carlos', "hola_soy_carlos_y_no_juego_league_of_legends")
aternos.iniciar_sesion('Jp', "hola_soy_jp_y_no_se_si_me_gusta_league_of_legends")
#desconectamos a dos de los jugadores
aternos.desconectar('andré')

#si desconectamos jugadores ya desconectados o que no existe lanza un keyerror, pero se maneja con el try/except
aternos.desconectar('vendo_choripan')

# %%
#ahora veremos que ocurre si intentamos iniciar sesión con una contraseña menor a 8 caracteres, se lanza un ValueError, pero se maneja con el try/except


aternos_2 = Aternos()

aternos_2.iniciar_sesion('Josefa2', "hola")

# %% [markdown]
# ## Resumen de Iterables e Iteradores 🔁
#
# ### 🔑 Conceptos clave
#
# | **Concepto** | **Qué es** | **Cómo se obtiene / implementa** |
# |:-------------|:-----------|:----------------------------------|
# | **Iterable** | Objeto que contiene una colección y puede recorrerse con `for` | Implementa `__iter__()` (retorna un **iterador**) **o** `__getitem__()` (indexable; debe lanzar `IndexError` al llegar al final) |
# | **Iterador** | Objeto que va entregando los elementos de un iterable, uno a uno | Implementa `__next__()` (retorna el siguiente valor) y `__iter__()` (retorna `self`) |
# | **Fin de la iteración** | Señal de que ya no quedan elementos por recorrer | El iterador lanza `StopIteration` dentro de `__next__()` |
# | **Generador** | Iterador especial, creado con una sintaxis parecida a la comprensión de listas | No guarda todos los valores en memoria; se agota tras recorrerlo una vez |
#
# ### ⚙️ Resumen esencial de sintaxis
#
# | **Categoría** | **Comando / Sintaxis** | **Descripción breve** | **Ejemplo** |
# |:--------------|:-----------------------|:----------------------|:------------|
# | **Obtener iterador** | `iter(iterable)` | Llama a `iterable.__iter__()` y retorna un iterador nuevo | `it = iter({1,2,3})` |
# | **Avanzar** | `next(iterador)` | Llama a `iterador.__next__()` y retorna el siguiente valor | `next(it)` |
# | **Recorrer** | `for x in iterable:` | Pide un iterador y llama a `next()` hasta capturar `StopIteration` | `for item in {1,2,3}: ...` |
# | **Terminar iteración** | `raise StopIteration("mensaje")` | Señala que no quedan elementos; el `for` la captura automáticamente | Dentro de `__next__` |
# | **Reutilizar** | — | Un **iterable** puede recorrerse múltiples veces (crea un iterador nuevo cada vez); un **iterador** solo una vez | `for` dos veces sobre el mismo iterable funciona |
# | **Generador por comprensión** | `(expr for x in seq)` | Crea un generador; se usan `()` en vez de `[]` | `(2 * i for i in range(10))` |
# | **Generador — filtrar** | `(expr for x in seq if cond)` | El `if` al final **descarta** los elementos que no cumplen la condición | `(i for i in range(10) if i < 3)` |
# | **Generador — transformar** | `(a if cond else b for x in seq)` | El `if-else` en línea **cambia** el valor generado, sin filtrar ninguno | `(i if i < 3 else 3 for i in range(10))` |
#
# > 💡 **Iterable vs. iterador:** todo **iterador** es también un **iterable** (implementa `__iter__` retornando `self`), pero no todo iterable es un iterador. Los generadores son iteradores automáticos: no necesitas escribir una clase, Python construye el objeto por ti.
#
# > ⚠️ **`__getitem__` como alternativa:** si un objeto no implementa `__iter__`, Python intentará iterarlo llamando a `__getitem__(0)`, `__getitem__(1)`, ... hasta que se lance un `IndexError`. Es una forma más antigua e implícita de volver algo iterable.

# %% [markdown]
# ## Ejercicio 2: El Bundle de Exploración 🎒
# Te estás preparando para ir al *End* a derrotar a la dragona con tus amigos. Como el servidor tiene un poco de lag, necesitas ser eficiente con tus recursos. Has decidido crear un sistema para gestionar tus **Bundles** de combate usando los conceptos de la semana 5 de Avanzada. Un **Bundle** es un ítem de utilidad que permite agrupar hasta 64 objetos distintos en una sola ranura de tu inventario. En programación, el Bundle es el **Iterable** perfecto: un contenedor que guarda una colección (en este caso, una `deque` de tuplas con el nombre del ítem y su cantidad). El **Iterador**, por otro lado, es la "mano" que va rebuscando y extrayendo los objetos uno por uno. Una vez que sacas el último ítem, el saco queda vacío y, al intentar sacar otro, el sistema nos lanza un `StopIteration`
#
# Deberás implementar un sistema donde un Bundle sea **Iterable** y posea su propio **Iterador** personalizado:
#
# - `IterableBundle`: Representa el saco de ítems.
#   - `__init__`: Recibe una `deque` con tuplas de tipo `(nombre_item, cantidad)`.
#   - `__iter__`: Debe retornar una instancia del iterador `IteradorBundle`, pasándole los ítems.
#
# - `IteradorBundle`: Es el encargado de sacar los ítems del saco.
#   - `__init__`: Recibe los ítems. Para no vaciar el Bundle original accidentalmente, debe trabajar con una **copia** de la `deque` (`.copy()`) y que debe estar  *`ordenada de menor a mayor cantidad de items`*. Además debe tener un atributo `desde_la_izquierda` que indique si el próximo ítem a sacar es el primero de la izquierda o el último de la derecha (inicialmente `True`).
#   - `__next__`: Cada vez que se llame debe sacar un ítem. Si el saco está vacío, debe lanzar un `StopIteration` con el mensaje `"No hay más items en tu Bundle"`. Si `desde_la_izquierda` es `True`, debe sacar el ítem de la izquierda (`popleft()`), si es `False`, debe sacar el ítem de la derecha (`pop()`). Luego de sacar el ítem, debe alternar el valor de `desde_la_izquierda` para que el próximo saque sea del lado opuesto.
#
# En el menú de pruebas, deberás usar `try` y `except` para manejar los posibles errores:
# 1. **`NameError`**: Si el usuario intenta usar `next()` sin haber creado el iterador primero.
# 2. **`StopIteration`**: Para capturar el momento en que el saco se vacía y mostrar el mensaje de error correspondiente.
#
# > **HINT**: Para ordenar la `deque` de menor a mayor cantidad de items, puedes usar la función `sorted()` con una clave personalizada. Por ejemplo: `sorted(items, key=lambda x: x[1])` ordenará los ítems basándose en la cantidad (el segundo elemento de la tupla), las funciones lambdas se veran en profundidad en programación funcional.
#
# > **Dato curioso**: Los Bundles en Minecraft se craftean con piel y de conejo... pero aquí los crafteamos con puro Python. 🐰
#
# > **Dato curioso de Minecraft**: Aunque en el juego un Bundle puede guardar hasta 64 ítems diferentes mezclados, en nuestro código usamos una `deque` porque nos permite sacar elementos de forma muy eficiente por la izquierda (`popleft`), simulando que los ítems están ordenados uno tras otro en el fondo del saco. 🎒
#
# > **BONUS**: Un gran desafio seria implementar el correcto modelamiento de los items. Para esto ocupa properties para que el usuario no pueda ingresar una cantidad negativa, una cantidad > 64 o un nombre de item vacio (asignar un item llamado `"Ítem Inválido"`). Si el usuario intenta ingresar un valor no valido, hace un `raise` de una excepción que tu mismo definas, por ejemplo `InvalidItemError` con un mensaje que explique el error. Otro desafio seria implementar un método `combinar_items` que permita combinar dos items iguales en uno solo, sumando sus cantidades (sin exceder el límite de 64). Si la combinación excede el límite, el método debería lanzar una excepción `ItemOverflowError` con un mensaje que explique el error.
#
# > **Hint**: Para definir tus propias excepciones, puedes crear una clase que herede de `Exception`. Por ejemplo:
#
# ```python
# class InvalidItemError(Exception):
#     pass

# %%
from __future__ import annotations
from collections import deque


class IterableBundle:
    #items es una deque de tuplas (str, int) donde el str es el nombre del item y el int es la cantidad del item
    def __init__(self, items: deque[str, int]) -> None:
        self.items = items
    #definimos el iterador de la clase Bundle, el iterador se encargará de recorrer la deque de items y devolver cada item uno por uno, junto a su cantidad.
    def __iter__(self) -> IteradorBundle:
        return IteradorBundle(self.items)

class IteradorBundle:
    #creamos una copia de la deque de items para no modificar la original, y poder recorrerla sin problemas.
    def __init__(self, iterable: deque[str, int]) -> None:
        self.iterable = deque(sorted(iterable.copy(), key = lambda item: item[1]))
        self.desde_la_izquierda = True
    #definimos el método __next__ para devolver el siguiente item de la deque, si la deque está vacía, se lanza una excepción StopIteration para indicar que no hay más items que recorrer.
    def __next__(self) -> tuple[str, int]:
        if not self.iterable:
            raise StopIteration("No hay mas items en tu Bundle")
        
        if self.desde_la_izquierda:
            item = self.iterable.popleft()
        else:
            item = self.iterable.pop()
        self.desde_la_izquierda = not self.desde_la_izquierda
        return item
### prueba
bundle = IterableBundle(deque([("Espada", 1), ("Pocion", 3), ("Escudo", 2), 
                    ("netherite", 64), ("manzana dorada", 5), ("arco", 1)]))

menu_run = True
while menu_run:
    print("1. Recorrer Bundle")
    print("2. Crear Iterador")
    print("3. iterador_next")
    print("4. Salir")
    
    opcion = input("Ingrese una opción: ")
    
    if opcion == "1":
        for item in bundle:
            print(item, end = ' ')

    elif opcion == "2":
        bundle_iter = iter(bundle)
        print("Iterador creado exitosamente")

    elif opcion == "3":
        try:
            print(next(bundle_iter))
        except NameError:
            print("Primero debes crear un iterador")
        except StopIteration as e:
            print(e)
            
    elif opcion == "4":
        menu_run = False
        print("Gracias por usar el programa novatito :)")

# %% [markdown]
# ## Resumen de Listas Ligadas 🔗
#
# ### 🔑 Conceptos clave
#
# | **Concepto** | **Qué es** | **Detalle** |
# |:-------------|:-----------|:-------------|
# | **Nodo** | Unidad mínima que guarda un dato y referencias a sus nodos vecinos | Atributos típicos: `valor` (dato) y `siguiente` (referencia al próximo nodo) |
# | **Head (cabeza)** | Primer nodo de la lista | Punto de entrada para recorrer toda la estructura |
# | **Tail (cola)** | Último nodo de la lista | Su atributo `siguiente` (o `next`) es `None` |
# | **Lista simplemente ligada** | Cada nodo referencia solo a su sucesor (`siguiente`) | Solo se puede recorrer en un sentido |
# | **Lista doblemente ligada** | Cada nodo referencia a su sucesor **y** a su predecesor (`next` / `previous`) | Permite recorrer en ambos sentidos; es la que usa el Ejercicio 3 con las Shulkers |
#
# ### ⚙️ Resumen esencial de operaciones
#
# | **Categoría** | **Operación** | **Descripción breve** |
# |:--------------|:---------------|:------------------------|
# | **Agregar al final** | `agregar(valor)` | Crea un nodo y lo conecta como sucesor del nodo cola actual; actualiza la cola |
# | **Agregar al inicio** | `insertar(valor, 0)` | El nuevo nodo pasa a ser la cabeza; su `siguiente` apunta a la antigua cabeza |
# | **Obtener** | `obtener(posicion)` | Recorre desde la cabeza, nodo a nodo, hasta llegar a `posicion` |
# | **Insertar en posición** | `insertar(valor, posicion)` | Busca el nodo predecesor y engancha el nuevo nodo entre él y su sucesor |
# | **Eliminar** | `pop` / `popleft` / `remove` | Actualiza los punteros de los nodos vecinos para "saltarse" el nodo eliminado |
# | **Largo** | `len(lista)` / `__len__` | Recorre toda la lista contando nodos hasta llegar a `None` |
# | **Recorrer con `for`** | Implementar `__iter__` / `__next__` | Una clase iteradora guarda el `nodo_actual` y avanza siguiendo `siguiente`/`next` |
#
# > 💡 **Conexión con excepciones:** como no hay acceso indexado, "pasarse" del final de la lista (acceder a `.siguiente`/`.next` cuando el nodo ya es `None`) no lanza `IndexError` como en una `list` de Python, sino un `AttributeError` (intentar acceder a un atributo de `None`). Por eso el Ejercicio 3 pide capturar `AttributeError` para manejar esos casos límite.
#
# > ⚠️ **Simple vs. doble:** en una lista **simplemente** ligada (como `ListaLigada` de los contenidos) solo se puede avanzar hacia adelante; en una lista **doblemente** ligada (como `ShulkersLigadas` del Ejercicio 3) cada nodo conoce a su vecino anterior y siguiente, lo que facilita operaciones como eliminar el último elemento o recorrer en reversa, a costa de mantener el doble de punteros actualizados en cada operación.

# %% [markdown]
# ## Ejercicio 3: Shulker Boxes Ligadas 😱📦
#
# ¡Victoria! La dragona del End ha caído y el portal a las **End Cities** se ha abierto. Has pasado horas saqueando barcos voladores y torres, recolectando elitras y armaduras. Sin embargo, te das cuenta de que el inventario de un jugador normal no da abasto para tanto botín.
#
# Para solucionar esto, has diseñado un sistema de **Shulkers Ligadas**. Te encuentras explorando las islas flotantes y has acumulado tantas Shulker Boxes que decidiste unirlas todas en un "tren de carga" para llevarlas de vuelta al portal del Overworld. A diferencia de una lista simple, una **Lista Doblemente Ligada** permite que cada Shulker tenga un enganche hacia adelante (`next`) y uno hacia atrás (`previous`). Esto es vital: si el servidor de Aternos te da un tirón de lag mientras cruzas el vacío, necesitas que tus cajas estén bien amarradas por ambos lados para no perder el rastro de tu loot.
#
# Justo cuando escuchas el sonido de un Enderman teletransportándose detrás de ti, abres tu consola de comandos y aplicas tus conocimientos de `lista ligadas`. GRACIAS A DCCRAFT, ¡TU ENTENDIMIENTO DE LAS ESTRUCTURAS DE DATOS TE SALVA LA VIDA!
#
# Tu misión es implementar la logística del tren en la clase `ShulkersLigadas`. Debes completar los siguientes métodos siguiendo estas reglas:
#
# #### 1. Clase `ShulkerBox` (El Nodo) - **YA IMPLEMENTADA**
# Representa un vagón individual de tu tren. No debes modificarla, solo usar sus atributos:
# * **`items`**: Una lista de tuplas `(nombre, cantidad)` que representa el loot dentro de la caja.
# * **`next`**: Un puntero que apunta a la siguiente `ShulkerBox` en el tren. Si es el último vagón, es `None`.
# * **`previous`**: Un puntero que apunta a la `ShulkerBox` anterior. Si es la locomotora (`head`), es `None`.
#
# #### 2. Clase `ShulkersLigadas` (La Lista) - **POR IMPLEMENTAR**
# Es el sistema lógico que controla todo el tren. Su único atributo inicial es **`head`**, que apunta a la primera Shulker de la fila. Tu misión es programar los métodos de esta clase para que el tren pueda crecer, reducirse y organizarse sin que los vagones se pierdan en el vacío del End.
# 1.  **`appendleft_shulker(shulker)`**:
#     * Agrega una `ShulkerBox` al inicio de la lista (nueva `head`).
#     * Si la lista ya tiene elementos, debes conectar la antigua `head` con la nueva usando los punteros `next` y `previous`.
#
# 2.  **`append_shulker(actual_shulker, shulker)`**:
#     * **Recursivo**: Debe viajar por el tren hasta encontrar el último vagón (aquel que no tiene `next`).
#     * Una vez encontrado, conecta el nuevo vagón al final y establece el puntero `previous` hacia el vagón anterior.
#     * Usa `try/except AttributeError` para manejar el caso donde el tren esté inicialmente vacío.
#
# 3.  **`insert_shulker(current_shulker, new_shulker, pos_actual, pos_deseada)`**:
#     * **Recursivo**: Debe avanzar hasta la posición deseada.
#     * Al llegar, debe "abrir" el tren y meter la nueva Shulker al medio.
#     * **¡Cuidado!**: Debes actualizar 4 punteros: el `next` del anterior, el `previous` del siguiente, y los propios `next` y `previous` de la nueva Shulker.
#     * **Error**: Si la posición deseada no existe (el puntero cae en `None`), debes capturar el fallo ocupando `try/except AttributeError`  y, por seguridad, enganchar la Shulker al final del tren usando `append_shulker`.
#
# 4.  **`pop_shulker()` y `popleft_shulker()`**:
#     * Deben eliminar y retornar el vagón del final o del inicio respectivamente.
#     * Debes dejar los punteros del vagón eliminado en `None` y actualizar la nueva `head` o el nuevo final.
#     * **Error**: Al intentar acceder al vagón anterior (`previous`), si este es `None` (solo había un elemento), el `except AttributeError` debe capturar el error para resetear la `head` a `None`.
#     * **Error 2**: Si tras eliminar la cabeza el tren queda vacío, el `except AttributeError` debe capturar el intento de actualizar el `previous` de la nueva (inexistente) cabeza.
# 5. **`remove_shulker(current_shulker, pos_actual, pos_deseada)`**:
#     * **Recursivo**: Debe avanzar hasta la posicion deseada.
#     * Al llegar a la posición, debe eliminar el vagón y actualizar los punteros de los vagones adyacentes para mantener el tren unido.
#     * Similar a `insert_shulker`, debe actualizar los punteros de los vagones adyacentes para mantener el tren unido.
#     * **Error**: Si la posición no existe, el `except AttributeError` debe capturar el error y dejar el tren sin cambios.
# 6.  **`__repr__()`**:
#     * Debes retornar un `string` que muestre los items de cada Shulker en orden, separados por flechas (`->`), para visualizar el tren completo.
#
# > **Dato curioso**: Tu código usa `try` y `except` para capturar `AttributeError`. En el lore de DCCRAFT, esto funciona como un **sensor de proximidad**: si intentas conectar algo donde no hay nada (`None`), el sensor se activa y el código maneja la situación sin que el servidor crashee. 🚆💎

# %%
class ShulkerBox:
    def __init__(self, items: list[tuple[str, int]]):
        self.items = items
        self.next = None
        self.previous = None


class ShulkersLigadas:
    def __init__(self):
        self.head = None

    def appendleft_shulker(self, shulker: ShulkerBox):
        if not self.head:
            self.head = shulker
        else:
            cabeza = self.head
            cabeza.previous = shulker
            shulker.next = cabeza
            self.head = shulker
        
    def append_shulker(self, actual_shulker: ShulkerBox, shulker: ShulkerBox):
        try:
            if not actual_shulker.next:
                actual_shulker.next = shulker
                shulker.previous = actual_shulker
            else:
                self.append_shulker(actual_shulker.next, shulker)
        except AttributeError:
            # Captura si actual_shulker es None (lista inicialmente vacía)
            self.head = shulker

    def insert_shulker(self, current_shulker: ShulkerBox, new_shulker: ShulkerBox, 
                        posicion_actual: int, posicion_deseada: int):
        try:
            if posicion_actual == posicion_deseada:
                if current_shulker == self.head:
                    new_shulker.next = self.head
                    self.head.previous = new_shulker
                    self.head = new_shulker
                else:
                    anterior = current_shulker.previous
                    anterior.next = new_shulker
                    new_shulker.previous = anterior
                    
                    new_shulker.next = current_shulker
                    current_shulker.previous = new_shulker
            else:
                self.insert_shulker(current_shulker.next, new_shulker, 
                                    posicion_actual + 1, posicion_deseada)
        except AttributeError:
            # Captura si current_shulker es None (fuera de rango o lista vacía)
            self.append_shulker(self.head, new_shulker)

    def pop_shulker(self):
        if not self.head:
            print('No hay elementos que eliminar')
            return None
        
        shulker = self.head
        while shulker.next:
            shulker = shulker.next

        try:
            anterior = shulker.previous
            anterior.next = None
        except AttributeError:
            # Captura si shulker.previous es None (solo había 1 elemento en la lista)
            self.head = None
        
        shulker.previous = None
        return shulker

    def popleft_shulker(self):
        if not self.head:
            print('No hay elementos que eliminar')
            return None
        
        eliminado = self.head
        self.head = eliminado.next
        
        try:
            self.head.previous = None
        except AttributeError:
            # Captura si self.head es None (la lista quedó vacía tras el pop)
            pass

        eliminado.next = None
        return eliminado

    def remove_shulker(self, current_shulker: ShulkerBox, posicion_actual: int, posicion_deseada: int):
        try:
            if posicion_actual == posicion_deseada:
                anterior = current_shulker.previous
                siguiente = current_shulker.next

                if current_shulker == self.head:
                    self.head = siguiente
                    if self.head:
                        self.head.previous = None
                else:
                    anterior.next = siguiente
                    if siguiente:
                        siguiente.previous = anterior

                current_shulker.next = None
                current_shulker.previous = None
            else:
                self.remove_shulker(current_shulker.next, posicion_actual + 1, posicion_deseada)
        except AttributeError:
            # Captura si current_shulker es None (índice fuera de rango)
            pass
    def __repr__(self) -> str:
        """
        Forma una representación de la lista
        """
        string = ""
        nodo_actual = self.head
        while nodo_actual is not None:
            string = f"{string}{nodo_actual.items} → "
            nodo_actual = nodo_actual.next
        return string
        
        
    
#ejemplos 
shulker1 = ShulkerBox([("Espada", 1), ("Pocion", 3), ("Escudo", 2)])
shulker2 = ShulkerBox([("Manzana", 5), ("Arco", 1)])
shulker3 = ShulkerBox([("Hacha", 2), ("Pocion de velocidad", 4)])
shulker4 = ShulkerBox([("Pico", 1), ("Pocion de fuerza", 2)])
shulkers = ShulkersLigadas()
shulkers.appendleft_shulker(shulker1)
print(shulkers)
shulkers.append_shulker(shulkers.head, shulker2)
print(shulkers)
shulkers.insert_shulker(shulkers.head, shulker3, 0, 1)
print(shulkers)
shulkers.insert_shulker(shulkers.head, shulker4, 0, 10)
print(shulkers)
shulkers.remove_shulker(shulkers.head, 0, 1)
print(shulkers)
shulkers.popleft_shulker()
print(shulkers)
shulkers.pop_shulker()  
print(shulkers)

# %% [markdown]
# ## Ejercicio 4: El Clasificador de Hoppers 🚰 *(en papel, sin computador)*
#
# > ✍️ **Este ejercicio se resuelve escribiendo pseudocódigo a mano, tal como podría pedirse en la prueba escrita.** No es requisito que tu pseudocódigo siga estrictamente la sintaxis de Python: basta con que **se entienda cada paso que sigue tu código**. Lo que se corrige es la lógica, no si te faltó un `:` o si la indentación quedó pareja.
#
# Ya de vuelta en el Overworld con todo el loot guardado, decides automatizar la base y construir un **clasificador de hoppers** (embudos). Y aquí viene lo bonito: los hoppers de Minecraft se encadenan uno tras otro y se pasan los ítems **en una sola dirección**, donde cada hopper conoce únicamente al **siguiente**. Es decir, un clasificador de hoppers es, literalmente, una **lista simplemente ligada**. 🤯
#
# En tu cinta pueden pasar dos cosas distintas:
#
# - Un hopper **vacío** (`cantidad == 0`) no aporta nada, pero **no corta la cinta**: los ítems siguen pasando de largo hacia el siguiente hopper.
# - Un hopper **bloqueado** por una señal de redstone (`bloqueado == True`) **sí corta la cinta**: de ahí en adelante no pasa absolutamente nada más.
#
# El siguiente código **ya está implementado y no debes modificarlo**:
#
# ```python
# class Hopper:
#     def __init__(self, item, cantidad, bloqueado=False):
#         self.item = item            # nombre del ítem (str)
#         self.cantidad = cantidad    # cuántos hay (int)
#         self.bloqueado = bloqueado  # ¿hay una señal de redstone activa? (bool)
#         self.siguiente = None       # siguiente Hopper de la cinta, o None si es el último
#
#
# class CintaHoppers:
#     def __init__(self):
#         self.cabeza = None
#         self.cola = None
#
#     def conectar(self, hopper):
#         # engancha un hopper al final de la cinta
#         if self.cabeza is None:
#             self.cabeza = hopper
#             self.cola = hopper
#             return
#         self.cola.siguiente = hopper
#         self.cola = hopper
#
#     def __iter__(self):
#         return IteradorCintaHoppers(self.cabeza)
#
#
# class IteradorCintaHoppers:
#     def __init__(self, cabeza):
#         self.actual = cabeza
# ```
#
# Y así se usa la cinta una vez terminada:
#
# ```python
# for item, cantidad in cinta:
#     print("Pasó por la cinta:", cantidad, "x", item)
# ```
#
# ### Parte A 📝
#
# Escribe **en pseudocódigo** el método `__next__` de `IteradorCintaHoppers`, de manera que al recorrer la cinta con un `for`:
#
# 1. Entregue una tupla `(item, cantidad)` por cada hopper que **tenga ítems**.
# 2. **Se salte** los hoppers vacíos y siga avanzando por la cinta.
# 3. Levante `StopIteration("La cinta llegó al final")` cuando ya no queden hoppers por revisar.
# 4. Levante `StopIteration("Un hopper bloqueado detuvo la cinta")` apenas se tope con un hopper bloqueado, **sin entregar su contenido** (aunque tuviera ítems).
#
# **Restricciones** (iguales a las de una pregunta de prueba):
#
# - Solo puedes usar la **lista ligada**. No puedes usar `list`, `dict`, `set`, `deque`, ni convertir la cinta a otra estructura.
# - No puedes modificar `Hopper`, `CintaHoppers` ni el `__init__` del iterador.
# - Sí puedes agregarle atributos nuevos al iterador, siempre que los declares explícitamente.
#
# ### Parte B 💭 *(3 líneas, sin código)*
#
# Fíjate en que `CintaHoppers.__iter__` construye una **instancia nueva** de `IteradorCintaHoppers` cada vez que se le llama. Supón que en vez de eso la cinta creara **un solo** iterador en su `__init__` y lo retornara siempre el mismo. ¿Qué pasaría si recorremos la misma cinta con **dos `for` seguidos**? Justifica usando la diferencia entre *iterable* e *iterador*.

# %% [markdown]
# ### ✅ Pauta Ejercicio 4
#
# #### Parte A — Posible respuesta
#
# ```python
# def __next__(self):
#     while True:
#         # 1. ¿Se acabó la cinta?
#         if self.actual is None:
#             raise StopIteration("La cinta llegó al final")
#
#         # 2. ¿Hay redstone bloqueando el paso? Cortamos antes de mirar el contenido
#         if self.actual.bloqueado:
#             raise StopIteration("Un hopper bloqueado detuvo la cinta")
#
#         # 3. Guardamos el hopper actual y AVANZAMOS antes de retornar
#         hopper = self.actual
#         self.actual = self.actual.siguiente
#
#         # 4. Si tenía ítems lo entregamos; si estaba vacío, el while da otra vuelta
#         if hopper.cantidad > 0:
#             return (hopper.item, hopper.cantidad)
# ```
#
# #### Errores frecuentes 🚨
#
# | Error | Por qué está mal |
# |:------|:-----------------|
# | `return StopIteration(...)` | `StopIteration` **se levanta** con `raise`, no se retorna. Retornarla haría que el `for` entregue el objeto excepción como si fuera un ítem. |
# | Usar un `for` sobre `self.actual` | Un `Hopper` no es iterable: se recorre siguiendo `.siguiente` a mano. |
# | Un solo `if` para saltar vacíos | Con `if` solo se salta **un** hopper vacío; si hay dos seguidos, el segundo se cuela. Por eso el salto necesita `while` o recursión. |
# | Revisar `bloqueado` después de entregar el ítem | El enunciado pide cortar **antes**: un hopper bloqueado no entrega nada, aunque esté lleno. |
# | Avanzar `self.actual` después del `return` | El código después de un `return` nunca se ejecuta ⇒ `for` infinito. |
#
# #### Parte B
#
# Si `__iter__` retornara siempre **el mismo** iterador, el primer `for` lo consumiría por completo (quedaría con `self.actual is None`) y el segundo `for` **terminaría de inmediato sin entregar nada**, porque su primera llamada a `__next__` levantaría `StopIteration` al tiro.
#
# La razón es la diferencia entre los dos conceptos: un **iterable** puede recorrerse muchas veces justamente porque **fabrica un iterador nuevo** en cada `__iter__`; un **iterador** guarda el estado del recorrido y por eso **se agota una sola vez**.
